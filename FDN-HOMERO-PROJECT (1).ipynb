# %% [markdown]
# # FDN ANALYSIS REGRESION LINEAL

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Tus datos
data = {
    "actual": [
        37.857, 34.558, 32.574, 34.660, 31.539, 31.539, 43.527, 34.625, 28.363, 39.570,
        39.570, 38.361, 41.160, 37.456, 37.068, 30.781, 38.162, 33.496, 36.081, 38.133,
        32.189, 39.347, 40.948, 34.635, 34.660, 37.857, 34.192, 33.715, 39.330, 34.335,
        42.973, 33.647, 42.973, 38.182, 34.192, 40.657, 40.464, 41.775, 36.858, 33.530,
        41.000, 42.324, 37.519, 34.660, 33.530, 42.788, 35.221, 31.020, 33.715, 37.068,
        38.572, 37.845, 43.527, 31.539, 34.608, 37.519, 38.182, 40.977, 37.586, 38.960,
        34.247, 42.650, 41.000, 31.545, 35.615, 38.572, 38.162, 38.199, 33.715, 37.242,
        31.910, 37.132, 34.993, 34.660, 41.449, 33.496, 30.781, 34.248, 41.449, 41.907,
        36.081, 41.837, 29.790, 39.617, 39.330, 39.537, 37.586, 37.242, 42.788, 41.160,
        38.960, 38.415, 39.537, 37.845, 35.093, 37.456, 41.449, 39.047, 37.312, 31.545,
        39.537, 37.312, 29.300, 33.683, 41.837, 38.133, 33.683, 42.324, 34.608, 39.347,
        34.192, 41.427, 35.121, 38.960, 32.574, 41.427, 37.242, 38.133, 37.857, 38.162,
        41.427, 34.558, 40.977, 37.586, 29.300, 37.132, 33.998, 32.189, 38.682, 41.907,
        34.660, 29.300, 33.647, 41.000, 42.234, 33.647, 34.635, 42.234, 40.948, 39.018,
        35.121, 40.021, 30.869, 32.189, 42.788, 37.611, 37.990, 38.361, 34.625, 29.790,
        28.363, 34.247, 41.907, 36.081, 31.020, 40.657, 29.790, 37.456, 38.199, 30.869,
        35.615, 30.781, 39.570, 31.910, 35.221, 39.047, 36.858, 40.464, 34.635, 37.611,
        31.910, 39.617, 41.837, 42.234, 37.979, 37.990, 39.347, 37.404, 40.021, 37.519,
        34.558, 42.650, 39.018, 41.775, 38.182, 28.363, 39.047, 37.990, 37.611, 42.324,
        38.415, 39.018, 37.979, 34.625, 38.572, 34.247, 38.361, 30.869, 39.617, 35.093,
        34.660, 34.993, 40.021, 38.199, 39.330, 35.121, 40.977, 37.068, 34.335, 35.093,
        41.160, 42.973, 37.404, 33.496, 37.312, 33.683, 42.650, 33.998, 37.979, 38.415,
        33.530, 37.404, 40.657, 31.545, 43.527, 35.221, 41.775, 34.335, 34.993, 37.132,
        38.682, 36.858, 34.608, 33.998, 40.464, 38.682, 34.248, 40.948, 34.248, 35.615,
        37.845, 32.574, 31.020
    ],
    "predicted": [
        38.682, 34.558, 34.192, 34.660, 31.539, 31.539, 42.973, 34.660, 28.363, 39.570,
        39.570, 37.312, 42.973, 39.617, 32.189, 29.790, 38.162, 33.496, 36.081, 38.133,
        32.189, 39.347, 40.948, 34.635, 34.625, 38.682, 32.574, 30.781, 39.330, 34.335,
        42.650, 33.647, 43.527, 38.182, 32.574, 40.657, 41.160, 41.775, 36.858, 35.121,
        42.234, 42.788, 37.519, 35.221, 37.132, 42.788, 35.221, 31.020, 31.545, 37.068,
        39.659, 37.979, 42.650, 31.539, 39.047, 37.979, 38.182, 40.977, 37.586, 38.960,
        34.625, 42.973, 41.449, 33.715, 35.615, 39.659, 37.586, 38.199, 31.545, 37.242,
        31.910, 37.132, 34.608, 34.660, 41.449, 33.496, 30.781, 33.683, 42.234, 41.907,
        36.081, 40.977, 34.192, 37.611, 39.330, 41.160, 37.586, 37.242, 42.788, 43.527,
        38.960, 38.415, 42.650, 37.845, 33.496, 37.456, 42.234, 39.047, 38.361, 33.715,
        39.537, 39.018, 29.300, 33.683, 41.160, 38.133, 34.248, 42.324, 34.993, 39.347,
        33.998, 42.324, 35.121, 38.960, 33.998, 42.324, 37.242, 38.133, 38.682, 38.162,
        42.324, 34.558, 41.837, 38.162, 30.869, 34.993, 33.998, 37.068, 38.682, 38.960,
        34.660, 29.300, 33.647, 41.000, 41.449, 33.647, 34.635, 41.449, 38.960, 39.018,
        33.530, 39.152, 30.869, 32.189, 42.788, 39.617, 37.990, 37.312, 34.625, 30.781,
        28.363, 34.247, 40.464, 36.081, 31.020, 40.657, 30.781, 37.611, 38.133, 30.869,
        35.615, 30.781, 39.570, 36.081, 35.221, 39.047, 36.858, 40.464, 34.635, 37.611,
        31.910, 37.456, 40.977, 41.000, 37.519, 37.990, 39.347, 37.404, 39.296, 37.519,
        34.558, 42.973, 39.018, 41.775, 38.182, 31.910, 39.047, 37.990, 37.611, 42.324,
        38.415, 39.018, 37.519, 34.247, 39.296, 34.247, 38.361, 30.869, 37.611, 33.496,
        34.625, 34.993, 39.152, 38.199, 39.330, 35.121, 41.449, 32.189, 34.335, 34.635,
        42.650, 42.650, 41.775, 33.496, 38.361, 34.248, 39.537, 33.998, 37.845, 37.857,
        35.121, 37.857, 40.657, 33.715, 42.650, 34.625, 41.775, 34.335, 34.993, 37.132,
        37.857, 38.162, 34.993, 34.192, 40.464, 38.682, 33.683, 40.948, 33.683, 35.615,
        37.845, 32.574, 28.363
    ]
}

# Crear DataFrame
df = pd.DataFrame(data)

# Ajustar regresión lineal
slope, intercept = np.polyfit(df['actual'], df['predicted'], 1)

# Predicciones basadas en el modelo lineal
y_pred = slope * df['actual'] + intercept

# Cálculo de R²
ss_res = np.sum((df['predicted'] - y_pred) ** 2)  # suma de residuos al cuadrado
ss_tot = np.sum((df['predicted'] - np.mean(df['predicted'])) ** 2)  # suma total
r2 = 1 - (ss_res / ss_tot)

print(f"Pendiente: {slope}")
print(f"Intercepto: {intercept}")
print(f"Coeficiente de determinación (R²): {r2}")

# Graficar
plt.figure(figsize=(10,6))
sns.scatterplot(x='actual', y='predicted', data=df, color='blue', label='Datos')
plt.plot(df['actual'], y_pred, color='red', label=f'Regresión lineal\n$R^2$={r2:.4f}')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Regresión lineal: Actual vs Predicted')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Pendiente: 0.9412177428912518
# Intercepto: 2.252291204870518
# Coeficiente de determinación (R²): 0.8916269629236419

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Tus datos
data = {
    "actual": [
        37.857, 34.558, 32.574, 34.660, 31.539, 31.539, 43.527, 34.625, 28.363, 39.570,
        39.570, 38.361, 41.160, 37.456, 37.068, 30.781, 38.162, 33.496, 36.081, 38.133,
        32.189, 39.347, 40.948, 34.635, 34.660, 37.857, 34.192, 33.715, 39.330, 34.335,
        42.973, 33.647, 42.973, 38.182, 34.192, 40.657, 40.464, 41.775, 36.858, 33.530,
        41.000, 42.324, 37.519, 34.660, 33.530, 42.788, 35.221, 31.020, 33.715, 37.068,
        38.572, 37.845, 43.527, 31.539, 34.608, 37.519, 38.182, 40.977, 37.586, 38.960,
        34.247, 42.650, 41.000, 31.545, 35.615, 38.572, 38.162, 38.199, 33.715, 37.242,
        31.910, 37.132, 34.993, 34.660, 41.449, 33.496, 30.781, 34.248, 41.449, 41.907,
        36.081, 41.837, 29.790, 39.617, 39.330, 39.537, 37.586, 37.242, 42.788, 41.160,
        38.960, 38.415, 39.537, 37.845, 35.093, 37.456, 41.449, 39.047, 37.312, 31.545,
        39.537, 37.312, 29.300, 33.683, 41.837, 38.133, 33.683, 42.324, 34.608, 39.347,
        34.192, 41.427, 35.121, 38.960, 32.574, 41.427, 37.242, 38.133, 37.857, 38.162,
        41.427, 34.558, 40.977, 37.586, 29.300, 37.132, 33.998, 32.189, 38.682, 41.907,
        34.660, 29.300, 33.647, 41.000, 42.234, 33.647, 34.635, 42.234, 40.948, 39.018,
        35.121, 40.021, 30.869, 32.189, 42.788, 37.611, 37.990, 38.361, 34.625, 29.790,
        28.363, 34.247, 41.907, 36.081, 31.020, 40.657, 29.790, 37.456, 38.199, 30.869,
        35.615, 30.781, 39.570, 31.910, 35.221, 39.047, 36.858, 40.464, 34.635, 37.611,
        31.910, 39.617, 41.837, 42.234, 37.979, 37.990, 39.347, 37.404, 40.021, 37.519,
        34.558, 42.650, 39.018, 41.775, 38.182, 28.363, 39.047, 37.990, 37.611, 42.324,
        38.415, 39.018, 37.979, 34.625, 38.572, 34.247, 38.361, 30.869, 39.617, 35.093,
        34.660, 34.993, 40.021, 38.199, 39.330, 35.121, 40.977, 37.068, 34.335, 35.093,
        41.160, 42.973, 37.404, 33.496, 37.312, 33.683, 42.650, 33.998, 37.979, 38.415,
        33.530, 37.404, 40.657, 31.545, 43.527, 35.221, 41.775, 34.335, 34.993, 37.132,
        38.682, 36.858, 34.608, 33.998, 40.464, 38.682, 34.248, 40.948, 34.248, 35.615,
        37.845, 32.574, 31.020
    ],
    "predicted": [
        38.682, 34.558, 34.192, 34.660, 31.539, 31.539, 42.973, 34.660, 28.363, 39.570,
        39.570, 37.312, 42.973, 39.617, 32.189, 29.790, 38.162, 33.496, 36.081, 38.133,
        32.189, 39.347, 40.948, 34.635, 34.625, 38.682, 32.574, 30.781, 39.330, 34.335,
        42.650, 33.647, 43.527, 38.182, 32.574, 40.657, 41.160, 41.775, 36.858, 35.121,
        42.234, 42.788, 37.519, 35.221, 37.132, 42.788, 35.221, 31.020, 31.545, 37.068,
        39.659, 37.979, 42.650, 31.539, 39.047, 37.979, 38.182, 40.977, 37.586, 38.960,
        34.625, 42.973, 41.449, 33.715, 35.615, 39.659, 37.586, 38.199, 31.545, 37.242,
        31.910, 37.132, 34.608, 34.660, 41.449, 33.496, 30.781, 33.683, 42.234, 41.907,
        36.081, 40.977, 34.192, 37.611, 39.330, 41.160, 37.586, 37.242, 42.788, 43.527,
        38.960, 38.415, 42.650, 37.845, 33.496, 37.456, 42.234, 39.047, 38.361, 33.715,
        39.537, 39.018, 29.300, 33.683, 41.160, 38.133, 34.248, 42.324, 34.993, 39.347,
        33.998, 42.324, 35.121, 38.960, 33.998, 42.324, 37.242, 38.133, 38.682, 38.162,
        42.324, 34.558, 41.837, 38.162, 30.869, 34.993, 33.998, 37.068, 38.682, 38.960,
        34.660, 29.300, 33.647, 41.000, 41.449, 33.647, 34.635, 41.449, 38.960, 39.018,
        33.530, 39.152, 30.869, 32.189, 42.788, 39.617, 37.990, 37.312, 34.625, 30.781,
        28.363, 34.247, 40.464, 36.081, 31.020, 40.657, 30.781, 37.611, 38.133, 30.869,
        35.615, 30.781, 39.570, 36.081, 35.221, 39.047, 36.858, 40.464, 34.635, 37.611,
        31.910, 37.456, 40.977, 41.000, 37.519, 37.990, 39.347, 37.404, 39.296, 37.519,
        34.558, 42.973, 39.018, 41.775, 38.182, 31.910, 39.047, 37.990, 37.611, 42.324,
        38.415, 39.018, 37.519, 34.247, 39.296, 34.247, 38.361, 30.869, 37.611, 33.496,
        34.625, 34.993, 39.152, 38.199, 39.330, 35.121, 41.449, 32.189, 34.335, 34.635,
        42.650, 42.650, 41.775, 33.496, 38.361, 34.248, 39.537, 33.998, 37.845, 37.857,
        35.121, 37.857, 40.657, 33.715, 42.650, 34.625, 41.775, 34.335, 34.993, 37.132,
        37.857, 38.162, 34.993, 34.192, 40.464, 38.682, 33.683, 40.948, 33.683, 35.615,
        37.845, 32.574, 28.363
    ]
}

# Crear DataFrame
df = pd.DataFrame(data)

# Ajustar regresión lineal
slope, intercept = np.polyfit(df['actual'], df['predicted'], 1)

# Predicciones basadas en el modelo lineal
y_pred = slope * df['actual'] + intercept

# Cálculo de R²
ss_res = np.sum((df['predicted'] - y_pred) ** 2)  # suma de residuos al cuadrado
ss_tot = np.sum((df['predicted'] - np.mean(df['predicted'])) ** 2)  # suma total
r2 = 1 - (ss_res / ss_tot)

print(f"Pendiente: {slope}")
print(f"Intercepto: {intercept}")
print(f"Coeficiente de determinación (R²): {r2}")

# Graficar
plt.figure(figsize=(10,6))
sns.scatterplot(x='actual', y='predicted', data=df, color='blue', label='Datos')
plt.plot(df['actual'], y_pred, color='red', label=f'Regresión lineal\n$R^2$={r2:.4f}')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Regresión lineal: Actual vs Predicted')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Pendiente: 0.9412177428912518
# Intercepto: 2.252291204870518
# Coeficiente de determinación (R²): 0.8916269629236419

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Tus datos
data = {
    "actual": [
        37.857, 34.558, 32.574, 34.660, 31.539, 31.539, 43.527, 34.625, 28.363, 39.570,
        39.570, 38.361, 41.160, 37.456, 37.068, 30.781, 38.162, 33.496, 36.081, 38.133,
        32.189, 39.347, 40.948, 34.635, 34.660, 37.857, 34.192, 33.715, 39.330, 34.335,
        42.973, 33.647, 42.973, 38.182, 34.192, 40.657, 40.464, 41.775, 36.858, 33.530,
        41.000, 42.324, 37.519, 34.660, 33.530, 42.788, 35.221, 31.020, 33.715, 37.068,
        38.572, 37.845, 43.527, 31.539, 34.608, 37.519, 38.182, 40.977, 37.586, 38.960,
        34.247, 42.650, 41.000, 31.545, 35.615, 38.572, 38.162, 38.199, 33.715, 37.242,
        31.910, 37.132, 34.993, 34.660, 41.449, 33.496, 30.781, 34.248, 41.449, 41.907,
        36.081, 41.837, 29.790, 39.617, 39.330, 39.537, 37.586, 37.242, 42.788, 41.160,
        38.960, 38.415, 39.537, 37.845, 35.093, 37.456, 41.449, 39.047, 37.312, 31.545,
        39.537, 37.312, 29.300, 33.683, 41.837, 38.133, 33.683, 42.324, 34.608, 39.347,
        34.192, 41.427, 35.121, 38.960, 32.574, 41.427, 37.242, 38.133, 37.857, 38.162,
        41.427, 34.558, 40.977, 37.586, 29.300, 37.132, 33.998, 32.189, 38.682, 41.907,
        34.660, 29.300, 33.647, 41.000, 42.234, 33.647, 34.635, 42.234, 40.948, 39.018,
        35.121, 40.021, 30.869, 32.189, 42.788, 37.611, 37.990, 38.361, 34.625, 29.790,
        28.363, 34.247, 41.907, 36.081, 31.020, 40.657, 29.790, 37.456, 38.199, 30.869,
        35.615, 30.781, 39.570, 31.910, 35.221, 39.047, 36.858, 40.464, 34.635, 37.611,
        31.910, 39.617, 41.837, 42.234, 37.979, 37.990, 39.347, 37.404, 40.021, 37.519,
        34.558, 42.650, 39.018, 41.775, 38.182, 28.363, 39.047, 37.990, 37.611, 42.324,
        38.415, 39.018, 37.979, 34.625, 38.572, 34.247, 38.361, 30.869, 39.617, 35.093,
        34.660, 34.993, 40.021, 38.199, 39.330, 35.121, 40.977, 37.068, 34.335, 35.093,
        41.160, 42.973, 37.404, 33.496, 37.312, 33.683, 42.650, 33.998, 37.979, 38.415,
        33.530, 37.404, 40.657, 31.545, 43.527, 35.221, 41.775, 34.335, 34.993, 37.132,
        38.682, 36.858, 34.608, 33.998, 40.464, 38.682, 34.248, 40.948, 34.248, 35.615,
        37.845, 32.574, 31.020
    ],
    "predicted": [
        38.682, 34.558, 34.192, 34.660, 31.539, 31.539, 42.973, 34.660, 28.363, 39.570,
        39.570, 37.312, 42.973, 39.617, 32.189, 29.790, 38.162, 33.496, 36.081, 38.133,
        32.189, 39.347, 40.948, 34.635, 34.625, 38.682, 32.574, 30.781, 39.330, 34.335,
        42.650, 33.647, 43.527, 38.182, 32.574, 40.657, 41.160, 41.775, 36.858, 35.121,
        42.234, 42.788, 37.519, 35.221, 37.132, 42.788, 35.221, 31.020, 31.545, 37.068,
        39.659, 37.979, 42.650, 31.539, 39.047, 37.979, 38.182, 40.977, 37.586, 38.960,
        34.625, 42.973, 41.449, 33.715, 35.615, 39.659, 37.586, 38.199, 31.545, 37.242,
        31.910, 37.132, 34.608, 34.660, 41.449, 33.496, 30.781, 33.683, 42.234, 41.907,
        36.081, 40.977, 34.192, 37.611, 39.330, 41.160, 37.586, 37.242, 42.788, 43.527,
        38.960, 38.415, 42.650, 37.845, 33.496, 37.456, 42.234, 39.047, 38.361, 33.715,
        39.537, 39.018, 29.300, 33.683, 41.160, 38.133, 34.248, 42.324, 34.993, 39.347,
        33.998, 42.324, 35.121, 38.960, 33.998, 42.324, 37.242, 38.133, 38.682, 38.162,
        42.324, 34.558, 41.837, 38.162, 30.869, 34.993, 33.998, 37.068, 38.682, 38.960,
        34.660, 29.300, 33.647, 41.000, 41.449, 33.647, 34.635, 41.449, 38.960, 39.018,
        33.530, 39.152, 30.869, 32.189, 42.788, 39.617, 37.990, 37.312, 34.625, 30.781,
        28.363, 34.247, 40.464, 36.081, 31.020, 40.657, 30.781, 37.611, 38.133, 30.869,
        35.615, 30.781, 39.570, 36.081, 35.221, 39.047, 36.858, 40.464, 34.635, 37.611,
        31.910, 37.456, 40.977, 41.000, 37.519, 37.990, 39.347, 37.404, 39.296, 37.519,
        34.558, 42.973, 39.018, 41.775, 38.182, 31.910, 39.047, 37.990, 37.611, 42.324,
        38.415, 39.018, 37.519, 34.247, 39.296, 34.247, 38.361, 30.869, 37.611, 33.496,
        34.625, 34.993, 39.152, 38.199, 39.330, 35.121, 41.449, 32.189, 34.335, 34.635,
        42.650, 42.650, 41.775, 33.496, 38.361, 34.248, 39.537, 33.998, 37.845, 37.857,
        35.121, 37.857, 40.657, 33.715, 42.650, 34.625, 41.775, 34.335, 34.993, 37.132,
        37.857, 38.162, 34.993, 34.192, 40.464, 38.682, 33.683, 40.948, 33.683, 35.615,
        37.845, 32.574, 28.363
    ]
}

# Crear DataFrame
df = pd.DataFrame(data)
# Ajustar regresión polinomial (grado 2)
grado = 2
coef_poly = np.polyfit(df['actual'], df['predicted'], grado)
polynomial = np.poly1d(coef_poly)
y_poly_pred = polynomial(df['actual'])

# Calcular R² para polinomial
ss_res = np.sum((df['predicted'] - y_poly_pred) ** 2)
ss_tot = np.sum((df['predicted'] - np.mean(df['predicted'])) ** 2)
r2_poly = 1 - (ss_res / ss_tot)

print(f"Coeficientes polinomio (grado {grado}):\n{coef_poly}")
print(f"Coeficiente de determinación (R² polinomial): {r2_poly:.4f}")

# Gráfico
plt.figure(figsize=(10, 6))

# Fondo sombreado
#plt.axhspan(df['predicted'].min(), df['predicted'].max(), facecolor='lightgrey', alpha=0.3)

# Puntos 'actual' vs 'predicted'
plt.scatter(df['actual'], df['predicted'], marker='o', color='green', label='Predicted (o)', alpha=0.6)
plt.scatter(df['actual'], df['actual'], marker='x', color='blue', label='Actual (x)', alpha=0.8)

# Ajuste polinomial (ordenar para trazar bonito)
x_range = np.linspace(df['actual'].min(), df['actual'].max(), 500)
y_fit = polynomial(x_range)
plt.plot(x_range, y_fit, color='red', linewidth=2, label=f'Ajuste polinomial (grado {grado})\n$R^2$={r2_poly:.4f}')

# Estética
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Dispersión Actual vs Predicted con ajuste polinomial')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Coeficientes polinomio (grado 2):
# [7.07035179e-03 4.24957555e-01 1.15836154e+01]
# Coeficiente de determinación (R² polinomial): 0.8924

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Tus datos
data = {
    "actual": [
        37.857, 34.558, 32.574, 34.660, 31.539, 31.539, 43.527, 34.625, 28.363, 39.570,
        39.570, 38.361, 41.160, 37.456, 37.068, 30.781, 38.162, 33.496, 36.081, 38.133,
        32.189, 39.347, 40.948, 34.635, 34.660, 37.857, 34.192, 33.715, 39.330, 34.335,
        42.973, 33.647, 42.973, 38.182, 34.192, 40.657, 40.464, 41.775, 36.858, 33.530,
        41.000, 42.324, 37.519, 34.660, 33.530, 42.788, 35.221, 31.020, 33.715, 37.068,
        38.572, 37.845, 43.527, 31.539, 34.608, 37.519, 38.182, 40.977, 37.586, 38.960,
        34.247, 42.650, 41.000, 31.545, 35.615, 38.572, 38.162, 38.199, 33.715, 37.242,
        31.910, 37.132, 34.993, 34.660, 41.449, 33.496, 30.781, 34.248, 41.449, 41.907,
        36.081, 41.837, 29.790, 39.617, 39.330, 39.537, 37.586, 37.242, 42.788, 41.160,
        38.960, 38.415, 39.537, 37.845, 35.093, 37.456, 41.449, 39.047, 37.312, 31.545,
        39.537, 37.312, 29.300, 33.683, 41.837, 38.133, 33.683, 42.324, 34.608, 39.347,
        34.192, 41.427, 35.121, 38.960, 32.574, 41.427, 37.242, 38.133, 37.857, 38.162,
        41.427, 34.558, 40.977, 37.586, 29.300, 37.132, 33.998, 32.189, 38.682, 41.907,
        34.660, 29.300, 33.647, 41.000, 42.234, 33.647, 34.635, 42.234, 40.948, 39.018,
        35.121, 40.021, 30.869, 32.189, 42.788, 37.611, 37.990, 38.361, 34.625, 29.790,
        28.363, 34.247, 41.907, 36.081, 31.020, 40.657, 29.790, 37.456, 38.199, 30.869,
        35.615, 30.781, 39.570, 31.910, 35.221, 39.047, 36.858, 40.464, 34.635, 37.611,
        31.910, 39.617, 41.837, 42.234, 37.979, 37.990, 39.347, 37.404, 40.021, 37.519,
        34.558, 42.650, 39.018, 41.775, 38.182, 28.363, 39.047, 37.990, 37.611, 42.324,
        38.415, 39.018, 37.979, 34.625, 38.572, 34.247, 38.361, 30.869, 39.617, 35.093,
        34.660, 34.993, 40.021, 38.199, 39.330, 35.121, 40.977, 37.068, 34.335, 35.093,
        41.160, 42.973, 37.404, 33.496, 37.312, 33.683, 42.650, 33.998, 37.979, 38.415,
        33.530, 37.404, 40.657, 31.545, 43.527, 35.221, 41.775, 34.335, 34.993, 37.132,
        38.682, 36.858, 34.608, 33.998, 40.464, 38.682, 34.248, 40.948, 34.248, 35.615,
        37.845, 32.574, 31.020
    ],
    "predicted": [
        38.682, 34.558, 34.192, 34.660, 31.539, 31.539, 42.973, 34.660, 28.363, 39.570,
        39.570, 37.312, 42.973, 39.617, 32.189, 29.790, 38.162, 33.496, 36.081, 38.133,
        32.189, 39.347, 40.948, 34.635, 34.625, 38.682, 32.574, 30.781, 39.330, 34.335,
        42.650, 33.647, 43.527, 38.182, 32.574, 40.657, 41.160, 41.775, 36.858, 35.121,
        42.234, 42.788, 37.519, 35.221, 37.132, 42.788, 35.221, 31.020, 31.545, 37.068,
        39.659, 37.979, 42.650, 31.539, 39.047, 37.979, 38.182, 40.977, 37.586, 38.960,
        34.625, 42.973, 41.449, 33.715, 35.615, 39.659, 37.586, 38.199, 31.545, 37.242,
        31.910, 37.132, 34.608, 34.660, 41.449, 33.496, 30.781, 33.683, 42.234, 41.907,
        36.081, 40.977, 34.192, 37.611, 39.330, 41.160, 37.586, 37.242, 42.788, 43.527,
        38.960, 38.415, 42.650, 37.845, 33.496, 37.456, 42.234, 39.047, 38.361, 33.715,
        39.537, 39.018, 29.300, 33.683, 41.160, 38.133, 34.248, 42.324, 34.993, 39.347,
        33.998, 42.324, 35.121, 38.960, 33.998, 42.324, 37.242, 38.133, 38.682, 38.162,
        42.324, 34.558, 41.837, 38.162, 30.869, 34.993, 33.998, 37.068, 38.682, 38.960,
        34.660, 29.300, 33.647, 41.000, 41.449, 33.647, 34.635, 41.449, 38.960, 39.018,
        33.530, 39.152, 30.869, 32.189, 42.788, 39.617, 37.990, 37.312, 34.625, 30.781,
        28.363, 34.247, 40.464, 36.081, 31.020, 40.657, 30.781, 37.611, 38.133, 30.869,
        35.615, 30.781, 39.570, 36.081, 35.221, 39.047, 36.858, 40.464, 34.635, 37.611,
        31.910, 37.456, 40.977, 41.000, 37.519, 37.990, 39.347, 37.404, 39.296, 37.519,
        34.558, 42.973, 39.018, 41.775, 38.182, 31.910, 39.047, 37.990, 37.611, 42.324,
        38.415, 39.018, 37.519, 34.247, 39.296, 34.247, 38.361, 30.869, 37.611, 33.496,
        34.625, 34.993, 39.152, 38.199, 39.330, 35.121, 41.449, 32.189, 34.335, 34.635,
        42.650, 42.650, 41.775, 33.496, 38.361, 34.248, 39.537, 33.998, 37.845, 37.857,
        35.121, 37.857, 40.657, 33.715, 42.650, 34.625, 41.775, 34.335, 34.993, 37.132,
        37.857, 38.162, 34.993, 34.192, 40.464, 38.682, 33.683, 40.948, 33.683, 35.615,
        37.845, 32.574, 28.363
    ]
}

df = pd.DataFrame(data)

# Ajustar regresión polinomial (grado 2)
grado = 2
coef_poly = np.polyfit(df['actual'], df['predicted'], grado)
polynomial = np.poly1d(coef_poly)
y_poly_pred = polynomial(df['actual'])

# Calcular R²
ss_res = np.sum((df['predicted'] - y_poly_pred) ** 2)
ss_tot = np.sum((df['predicted'] - np.mean(df['predicted'])) ** 2)
r2_poly = 1 - (ss_res / ss_tot)

# Mostrar R² redondeado a 2 decimales
print(f"{r2_poly:.2f}")
# Gráfico
plt.figure(figsize=(10, 6))

# Fondo sombreado
#plt.axhspan(df['predicted'].min(), df['predicted'].max(), facecolor='lightgrey', alpha=0.3)

# Puntos 'actual' vs 'predicted'
plt.scatter(df['actual'], df['predicted'], marker='o', color='green', label='Predicted (o)', alpha=0.6)
plt.scatter(df['actual'], df['actual'], marker='x', color='blue', label='Actual (x)', alpha=0.8)

# Ajuste polinomial (ordenar para trazar bonito)
x_range = np.linspace(df['actual'].min(), df['actual'].max(), 500)
y_fit = polynomial(x_range)
plt.plot(x_range, y_fit, color='red', linewidth=2, label=f'Ajuste polinomial (grado {grado})\n$R^2$={r2_poly:.4f}')

# Estética
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Dispersión Actual vs Predicted con ajuste polinomial')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 0.89

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Tus datos
data = {
    "actual": [
        37.857, 34.558, 32.574, 34.660, 31.539, 31.539, 43.527, 34.625, 28.363, 39.570,
        39.570, 38.361, 41.160, 37.456, 37.068, 30.781, 38.162, 33.496, 36.081, 38.133,
        32.189, 39.347, 40.948, 34.635, 34.660, 37.857, 34.192, 33.715, 39.330, 34.335,
        42.973, 33.647, 42.973, 38.182, 34.192, 40.657, 40.464, 41.775, 36.858, 33.530,
        41.000, 42.324, 37.519, 34.660, 33.530, 42.788, 35.221, 31.020, 33.715, 37.068,
        38.572, 37.845, 43.527, 31.539, 34.608, 37.519, 38.182, 40.977, 37.586, 38.960,
        34.247, 42.650, 41.000, 31.545, 35.615, 38.572, 38.162, 38.199, 33.715, 37.242,
        31.910, 37.132, 34.993, 34.660, 41.449, 33.496, 30.781, 34.248, 41.449, 41.907,
        36.081, 41.837, 29.790, 39.617, 39.330, 39.537, 37.586, 37.242, 42.788, 41.160,
        38.960, 38.415, 39.537, 37.845, 35.093, 37.456, 41.449, 39.047, 37.312, 31.545,
        39.537, 37.312, 29.300, 33.683, 41.837, 38.133, 33.683, 42.324, 34.608, 39.347,
        34.192, 41.427, 35.121, 38.960, 32.574, 41.427, 37.242, 38.133, 37.857, 38.162,
        41.427, 34.558, 40.977, 37.586, 29.300, 37.132, 33.998, 32.189, 38.682, 41.907,
        34.660, 29.300, 33.647, 41.000, 42.234, 33.647, 34.635, 42.234, 40.948, 39.018,
        35.121, 40.021, 30.869, 32.189, 42.788, 37.611, 37.990, 38.361, 34.625, 29.790,
        28.363, 34.247, 41.907, 36.081, 31.020, 40.657, 29.790, 37.456, 38.199, 30.869,
        35.615, 30.781, 39.570, 31.910, 35.221, 39.047, 36.858, 40.464, 34.635, 37.611,
        31.910, 39.617, 41.837, 42.234, 37.979, 37.990, 39.347, 37.404, 40.021, 37.519,
        34.558, 42.650, 39.018, 41.775, 38.182, 28.363, 39.047, 37.990, 37.611, 42.324,
        38.415, 39.018, 37.979, 34.625, 38.572, 34.247, 38.361, 30.869, 39.617, 35.093,
        34.660, 34.993, 40.021, 38.199, 39.330, 35.121, 40.977, 37.068, 34.335, 35.093,
        41.160, 42.973, 37.404, 33.496, 37.312, 33.683, 42.650, 33.998, 37.979, 38.415,
        33.530, 37.404, 40.657, 31.545, 43.527, 35.221, 41.775, 34.335, 34.993, 37.132,
        38.682, 36.858, 34.608, 33.998, 40.464, 38.682, 34.248, 40.948, 34.248, 35.615,
        37.845, 32.574, 31.020
    ],
    "predicted": [
        38.682, 34.558, 34.192, 34.660, 31.539, 31.539, 42.973, 34.660, 28.363, 39.570,
        39.570, 37.312, 42.973, 39.617, 32.189, 29.790, 38.162, 33.496, 36.081, 38.133,
        32.189, 39.347, 40.948, 34.635, 34.625, 38.682, 32.574, 30.781, 39.330, 34.335,
        42.650, 33.647, 43.527, 38.182, 32.574, 40.657, 41.160, 41.775, 36.858, 35.121,
        42.234, 42.788, 37.519, 35.221, 37.132, 42.788, 35.221, 31.020, 31.545, 37.068,
        39.659, 37.979, 42.650, 31.539, 39.047, 37.979, 38.182, 40.977, 37.586, 38.960,
        34.625, 42.973, 41.449, 33.715, 35.615, 39.659, 37.586, 38.199, 31.545, 37.242,
        31.910, 37.132, 34.608, 34.660, 41.449, 33.496, 30.781, 33.683, 42.234, 41.907,
        36.081, 40.977, 34.192, 37.611, 39.330, 41.160, 37.586, 37.242, 42.788, 43.527,
        38.960, 38.415, 42.650, 37.845, 33.496, 37.456, 42.234, 39.047, 38.361, 33.715,
        39.537, 39.018, 29.300, 33.683, 41.160, 38.133, 34.248, 42.324, 34.993, 39.347,
        33.998, 42.324, 35.121, 38.960, 33.998, 42.324, 37.242, 38.133, 38.682, 38.162,
        42.324, 34.558, 41.837, 38.162, 30.869, 34.993, 33.998, 37.068, 38.682, 38.960,
        34.660, 29.300, 33.647, 41.000, 41.449, 33.647, 34.635, 41.449, 38.960, 39.018,
        33.530, 39.152, 30.869, 32.189, 42.788, 39.617, 37.990, 37.312, 34.625, 30.781,
        28.363, 34.247, 40.464, 36.081, 31.020, 40.657, 30.781, 37.611, 38.133, 30.869,
        35.615, 30.781, 39.570, 36.081, 35.221, 39.047, 36.858, 40.464, 34.635, 37.611,
        31.910, 37.456, 40.977, 41.000, 37.519, 37.990, 39.347, 37.404, 39.296, 37.519,
        34.558, 42.973, 39.018, 41.775, 38.182, 31.910, 39.047, 37.990, 37.611, 42.324,
        38.415, 39.018, 37.519, 34.247, 39.296, 34.247, 38.361, 30.869, 37.611, 33.496,
        34.625, 34.993, 39.152, 38.199, 39.330, 35.121, 41.449, 32.189, 34.335, 34.635,
        42.650, 42.650, 41.775, 33.496, 38.361, 34.248, 39.537, 33.998, 37.845, 37.857,
        35.121, 37.857, 40.657, 33.715, 42.650, 34.625, 41.775, 34.335, 34.993, 37.132,
        37.857, 38.162, 34.993, 34.192, 40.464, 38.682, 33.683, 40.948, 33.683, 35.615,
        37.845, 32.574, 28.363
    ]
}

df = pd.DataFrame(data)

# Ajustar regresión polinomial (grado 2)
grado = 2
coef_poly = np.polyfit(df['actual'], df['predicted'], grado)
polynomial = np.poly1d(coef_poly)
y_poly_pred = polynomial(df['actual'])

# Calcular R²
ss_res = np.sum((df['predicted'] - y_poly_pred) ** 2)
ss_tot = np.sum((df['predicted'] - np.mean(df['predicted'])) ** 2)
r2_poly = 1 - (ss_res / ss_tot)

# Mostrar R² redondeado a 2 decimales
print(f"{r2_poly:.2f}")
# Gráfico
plt.figure(figsize=(10, 6))

# Fondo sombreado
#plt.axhspan(df['predicted'].min(), df['predicted'].max(), facecolor='lightgrey', alpha=0.3)

# Puntos 'actual' vs 'predicted'
plt.scatter(df['actual'], df['predicted'], marker='o', color='green', label='Predicted (o)', alpha=0.6)
plt.scatter(df['actual'], df['actual'], marker='x', color='blue', label='Actual (x)', alpha=0.8)

# Ajuste polinomial (ordenar para trazar bonito)
x_range = np.linspace(df['actual'].min(), df['actual'].max(), 500)
y_fit = polynomial(x_range)
plt.plot(x_range, y_fit, color='red', linewidth=2, label=f'Ajuste polinomial (grado {grado})\n$R^2$={r2_poly:.4f}')

# Estética
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Dispersión Actual vs Predicted con ajuste polinomial')
plt.legend()
plt.grid(True)
#exportar imagen
plt.savefig("FDN_FINISH_001.png", dpi=500, bbox_inches='tight')  
plt.show()
# Out:
# 0.89

# %%
cd Escritorio/homero/homero/
# Out:
# /home/marcos/Escritorio/homero/homero

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Tus datos
data = {
    "actual": [
        37.857, 34.558, 32.574, 34.660, 31.539, 31.539, 43.527, 34.625, 28.363, 39.570,
        39.570, 38.361, 41.160, 37.456, 37.068, 30.781, 38.162, 33.496, 36.081, 38.133,
        32.189, 39.347, 40.948, 34.635, 34.660, 37.857, 34.192, 33.715, 39.330, 34.335,
        42.973, 33.647, 42.973, 38.182, 34.192, 40.657, 40.464, 41.775, 36.858, 33.530,
        41.000, 42.324, 37.519, 34.660, 33.530, 42.788, 35.221, 31.020, 33.715, 37.068,
        38.572, 37.845, 43.527, 31.539, 34.608, 37.519, 38.182, 40.977, 37.586, 38.960,
        34.247, 42.650, 41.000, 31.545, 35.615, 38.572, 38.162, 38.199, 33.715, 37.242,
        31.910, 37.132, 34.993, 34.660, 41.449, 33.496, 30.781, 34.248, 41.449, 41.907,
        36.081, 41.837, 29.790, 39.617, 39.330, 39.537, 37.586, 37.242, 42.788, 41.160,
        38.960, 38.415, 39.537, 37.845, 35.093, 37.456, 41.449, 39.047, 37.312, 31.545,
        39.537, 37.312, 29.300, 33.683, 41.837, 38.133, 33.683, 42.324, 34.608, 39.347,
        34.192, 41.427, 35.121, 38.960, 32.574, 41.427, 37.242, 38.133, 37.857, 38.162,
        41.427, 34.558, 40.977, 37.586, 29.300, 37.132, 33.998, 32.189, 38.682, 41.907,
        34.660, 29.300, 33.647, 41.000, 42.234, 33.647, 34.635, 42.234, 40.948, 39.018,
        35.121, 40.021, 30.869, 32.189, 42.788, 37.611, 37.990, 38.361, 34.625, 29.790,
        28.363, 34.247, 41.907, 36.081, 31.020, 40.657, 29.790, 37.456, 38.199, 30.869,
        35.615, 30.781, 39.570, 31.910, 35.221, 39.047, 36.858, 40.464, 34.635, 37.611,
        31.910, 39.617, 41.837, 42.234, 37.979, 37.990, 39.347, 37.404, 40.021, 37.519,
        34.558, 42.650, 39.018, 41.775, 38.182, 28.363, 39.047, 37.990, 37.611, 42.324,
        38.415, 39.018, 37.979, 34.625, 38.572, 34.247, 38.361, 30.869, 39.617, 35.093,
        34.660, 34.993, 40.021, 38.199, 39.330, 35.121, 40.977, 37.068, 34.335, 35.093,
        41.160, 42.973, 37.404, 33.496, 37.312, 33.683, 42.650, 33.998, 37.979, 38.415,
        33.530, 37.404, 40.657, 31.545, 43.527, 35.221, 41.775, 34.335, 34.993, 37.132,
        38.682, 36.858, 34.608, 33.998, 40.464, 38.682, 34.248, 40.948, 34.248, 35.615,
        37.845, 32.574, 31.020
    ],
    "predicted": [
        38.682, 34.558, 34.192, 34.660, 31.539, 31.539, 42.973, 34.660, 28.363, 39.570,
        39.570, 37.312, 42.973, 39.617, 32.189, 29.790, 38.162, 33.496, 36.081, 38.133,
        32.189, 39.347, 40.948, 34.635, 34.625, 38.682, 32.574, 30.781, 39.330, 34.335,
        42.650, 33.647, 43.527, 38.182, 32.574, 40.657, 41.160, 41.775, 36.858, 35.121,
        42.234, 42.788, 37.519, 35.221, 37.132, 42.788, 35.221, 31.020, 31.545, 37.068,
        39.659, 37.979, 42.650, 31.539, 39.047, 37.979, 38.182, 40.977, 37.586, 38.960,
        34.625, 42.973, 41.449, 33.715, 35.615, 39.659, 37.586, 38.199, 31.545, 37.242,
        31.910, 37.132, 34.608, 34.660, 41.449, 33.496, 30.781, 33.683, 42.234, 41.907,
        36.081, 40.977, 34.192, 37.611, 39.330, 41.160, 37.586, 37.242, 42.788, 43.527,
        38.960, 38.415, 42.650, 37.845, 33.496, 37.456, 42.234, 39.047, 38.361, 33.715,
        39.537, 39.018, 29.300, 33.683, 41.160, 38.133, 34.248, 42.324, 34.993, 39.347,
        33.998, 42.324, 35.121, 38.960, 33.998, 42.324, 37.242, 38.133, 38.682, 38.162,
        42.324, 34.558, 41.837, 38.162, 30.869, 34.993, 33.998, 37.068, 38.682, 38.960,
        34.660, 29.300, 33.647, 41.000, 41.449, 33.647, 34.635, 41.449, 38.960, 39.018,
        33.530, 39.152, 30.869, 32.189, 42.788, 39.617, 37.990, 37.312, 34.625, 30.781,
        28.363, 34.247, 40.464, 36.081, 31.020, 40.657, 30.781, 37.611, 38.133, 30.869,
        35.615, 30.781, 39.570, 36.081, 35.221, 39.047, 36.858, 40.464, 34.635, 37.611,
        31.910, 37.456, 40.977, 41.000, 37.519, 37.990, 39.347, 37.404, 39.296, 37.519,
        34.558, 42.973, 39.018, 41.775, 38.182, 31.910, 39.047, 37.990, 37.611, 42.324,
        38.415, 39.018, 37.519, 34.247, 39.296, 34.247, 38.361, 30.869, 37.611, 33.496,
        34.625, 34.993, 39.152, 38.199, 39.330, 35.121, 41.449, 32.189, 34.335, 34.635,
        42.650, 42.650, 41.775, 33.496, 38.361, 34.248, 39.537, 33.998, 37.845, 37.857,
        35.121, 37.857, 40.657, 33.715, 42.650, 34.625, 41.775, 34.335, 34.993, 37.132,
        37.857, 38.162, 34.993, 34.192, 40.464, 38.682, 33.683, 40.948, 33.683, 35.615,
        37.845, 32.574, 28.363
    ]
}

df = pd.DataFrame(data)

# Ajustar regresión polinomial (grado 2)
grado = 2
coef_poly = np.polyfit(df['actual'], df['predicted'], grado)
polynomial = np.poly1d(coef_poly)
y_poly_pred = polynomial(df['actual'])

# Calcular R²
ss_res = np.sum((df['predicted'] - y_poly_pred) ** 2)
ss_tot = np.sum((df['predicted'] - np.mean(df['predicted'])) ** 2)
r2_poly = 1 - (ss_res / ss_tot)

# Mostrar R² redondeado a 2 decimales
print(f"{r2_poly:.2f}")
# Gráfico
plt.figure(figsize=(10, 6))

# Fondo sombreado
#plt.axhspan(df['predicted'].min(), df['predicted'].max(), facecolor='lightgrey', alpha=0.3)

# Puntos 'actual' vs 'predicted'
plt.scatter(df['actual'], df['predicted'], marker='x', color='orange', label='Predicted', s= 40, alpha=0.6)
plt.scatter(df['actual'], df['actual'], marker='o', color='deepskyblue', label='Actual', s= 100, alpha=0.8)

# Ajuste polinomial (ordenar para trazar bonito)
x_range = np.linspace(df['actual'].min(), df['actual'].max(), 500)
y_fit = polynomial(x_range)
plt.plot(x_range, y_fit, color='red', linewidth=2, label=f'$R^2$ = {r2_poly:.2f}')
# Estética
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Dispersión Actual vs Predicted con ajuste polinomial')
plt.legend()
plt.grid(True)
#exportar imagen
plt.savefig("FDN_FINISH_001.png", dpi=500, bbox_inches='tight')  
plt.show()
# Out:
# 0.89

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Tus datos
data = {
    "actual": [
        37.857, 34.558, 32.574, 34.660, 31.539, 31.539, 43.527, 34.625, 28.363, 39.570,
        39.570, 38.361, 41.160, 37.456, 37.068, 30.781, 38.162, 33.496, 36.081, 38.133,
        32.189, 39.347, 40.948, 34.635, 34.660, 37.857, 34.192, 33.715, 39.330, 34.335,
        42.973, 33.647, 42.973, 38.182, 34.192, 40.657, 40.464, 41.775, 36.858, 33.530,
        41.000, 42.324, 37.519, 34.660, 33.530, 42.788, 35.221, 31.020, 33.715, 37.068,
        38.572, 37.845, 43.527, 31.539, 34.608, 37.519, 38.182, 40.977, 37.586, 38.960,
        34.247, 42.650, 41.000, 31.545, 35.615, 38.572, 38.162, 38.199, 33.715, 37.242,
        31.910, 37.132, 34.993, 34.660, 41.449, 33.496, 30.781, 34.248, 41.449, 41.907,
        36.081, 41.837, 29.790, 39.617, 39.330, 39.537, 37.586, 37.242, 42.788, 41.160,
        38.960, 38.415, 39.537, 37.845, 35.093, 37.456, 41.449, 39.047, 37.312, 31.545,
        39.537, 37.312, 29.300, 33.683, 41.837, 38.133, 33.683, 42.324, 34.608, 39.347,
        34.192, 41.427, 35.121, 38.960, 32.574, 41.427, 37.242, 38.133, 37.857, 38.162,
        41.427, 34.558, 40.977, 37.586, 29.300, 37.132, 33.998, 32.189, 38.682, 41.907,
        34.660, 29.300, 33.647, 41.000, 42.234, 33.647, 34.635, 42.234, 40.948, 39.018,
        35.121, 40.021, 30.869, 32.189, 42.788, 37.611, 37.990, 38.361, 34.625, 29.790,
        28.363, 34.247, 41.907, 36.081, 31.020, 40.657, 29.790, 37.456, 38.199, 30.869,
        35.615, 30.781, 39.570, 31.910, 35.221, 39.047, 36.858, 40.464, 34.635, 37.611,
        31.910, 39.617, 41.837, 42.234, 37.979, 37.990, 39.347, 37.404, 40.021, 37.519,
        34.558, 42.650, 39.018, 41.775, 38.182, 28.363, 39.047, 37.990, 37.611, 42.324,
        38.415, 39.018, 37.979, 34.625, 38.572, 34.247, 38.361, 30.869, 39.617, 35.093,
        34.660, 34.993, 40.021, 38.199, 39.330, 35.121, 40.977, 37.068, 34.335, 35.093,
        41.160, 42.973, 37.404, 33.496, 37.312, 33.683, 42.650, 33.998, 37.979, 38.415,
        33.530, 37.404, 40.657, 31.545, 43.527, 35.221, 41.775, 34.335, 34.993, 37.132,
        38.682, 36.858, 34.608, 33.998, 40.464, 38.682, 34.248, 40.948, 34.248, 35.615,
        37.845, 32.574, 31.020
    ],
    "predicted": [
        38.682, 34.558, 34.192, 34.660, 31.539, 31.539, 42.973, 34.660, 28.363, 39.570,
        39.570, 37.312, 42.973, 39.617, 32.189, 29.790, 38.162, 33.496, 36.081, 38.133,
        32.189, 39.347, 40.948, 34.635, 34.625, 38.682, 32.574, 30.781, 39.330, 34.335,
        42.650, 33.647, 43.527, 38.182, 32.574, 40.657, 41.160, 41.775, 36.858, 35.121,
        42.234, 42.788, 37.519, 35.221, 37.132, 42.788, 35.221, 31.020, 31.545, 37.068,
        39.659, 37.979, 42.650, 31.539, 39.047, 37.979, 38.182, 40.977, 37.586, 38.960,
        34.625, 42.973, 41.449, 33.715, 35.615, 39.659, 37.586, 38.199, 31.545, 37.242,
        31.910, 37.132, 34.608, 34.660, 41.449, 33.496, 30.781, 33.683, 42.234, 41.907,
        36.081, 40.977, 34.192, 37.611, 39.330, 41.160, 37.586, 37.242, 42.788, 43.527,
        38.960, 38.415, 42.650, 37.845, 33.496, 37.456, 42.234, 39.047, 38.361, 33.715,
        39.537, 39.018, 29.300, 33.683, 41.160, 38.133, 34.248, 42.324, 34.993, 39.347,
        33.998, 42.324, 35.121, 38.960, 33.998, 42.324, 37.242, 38.133, 38.682, 38.162,
        42.324, 34.558, 41.837, 38.162, 30.869, 34.993, 33.998, 37.068, 38.682, 38.960,
        34.660, 29.300, 33.647, 41.000, 41.449, 33.647, 34.635, 41.449, 38.960, 39.018,
        33.530, 39.152, 30.869, 32.189, 42.788, 39.617, 37.990, 37.312, 34.625, 30.781,
        28.363, 34.247, 40.464, 36.081, 31.020, 40.657, 30.781, 37.611, 38.133, 30.869,
        35.615, 30.781, 39.570, 36.081, 35.221, 39.047, 36.858, 40.464, 34.635, 37.611,
        31.910, 37.456, 40.977, 41.000, 37.519, 37.990, 39.347, 37.404, 39.296, 37.519,
        34.558, 42.973, 39.018, 41.775, 38.182, 28.363, 39.047, 37.990, 37.611, 42.324,
        38.415, 39.018, 37.519, 34.247, 39.296, 34.247, 38.361, 30.869, 37.611, 33.496,
        34.625, 34.993, 39.152, 38.199, 39.330, 35.121, 41.449, 32.189, 34.335, 34.635,
        42.650, 42.650, 41.775, 33.496, 38.361, 34.248, 39.537, 33.998, 37.845, 37.857,
        35.121, 37.857, 40.657, 33.715, 42.650, 34.625, 41.775, 34.335, 34.993, 37.132,
        37.857, 38.162, 34.993, 34.192, 40.464, 38.682, 33.683, 40.948, 33.683, 35.615,
        37.845, 32.574, 28.363
    ]
}

df = pd.DataFrame(data)

# Ajustar regresión polinomial (grado 2)
grado = 2
coef_poly = np.polyfit(df['actual'], df['predicted'], grado)
polynomial = np.poly1d(coef_poly)
y_poly_pred = polynomial(df['actual'])

# Calcular R²
ss_res = np.sum((df['predicted'] - y_poly_pred) ** 2)
ss_tot = np.sum((df['predicted'] - np.mean(df['predicted'])) ** 2)
r2_poly = 1 - (ss_res / ss_tot)

# Mostrar R² redondeado a 2 decimales
print(f"{r2_poly:.2f}")
# Gráfico
plt.figure(figsize=(10, 6))

# Puntos 'actual' vs 'predicted'
plt.scatter(df['actual'], df['predicted'], marker='x', color='orange', label='Predicted', s=40, alpha=0.6)
plt.scatter(df['actual'], df['actual'], marker='o', color='deepskyblue', label='Actual', s=100, alpha=0.8)

# Ajuste polinomial (ordenar para trazar bonito)
x_range = np.linspace(df['actual'].min(), df['actual'].max(), 500)
y_fit = polynomial(x_range)
plt.plot(x_range, y_fit, color='red', linewidth=2, label='Polynomial fit')

# Añadir línea para R² en verde
plt.plot([], [], color='green', label=f'$R^2$ = {r2_poly:.2f}')

# Estética
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Dispersión Actual vs Predicted con ajuste polinomial')
plt.legend()
plt.grid(True)

# exportar imagen
plt.savefig("FDN_FINISH_001.png", dpi=500, bbox_inches='tight')  
plt.show()
# Out:
# 0.90

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Tus datos
data = {
    "actual": [
        37.857, 34.558, 32.574, 34.660, 31.539, 31.539, 43.527, 34.625, 28.363, 39.570,
        39.570, 38.361, 41.160, 37.456, 37.068, 30.781, 38.162, 33.496, 36.081, 38.133,
        32.189, 39.347, 40.948, 34.635, 34.660, 37.857, 34.192, 33.715, 39.330, 34.335,
        42.973, 33.647, 42.973, 38.182, 34.192, 40.657, 40.464, 41.775, 36.858, 33.530,
        41.000, 42.324, 37.519, 34.660, 33.530, 42.788, 35.221, 31.020, 33.715, 37.068,
        38.572, 37.845, 43.527, 31.539, 34.608, 37.519, 38.182, 40.977, 37.586, 38.960,
        34.247, 42.650, 41.000, 31.545, 35.615, 38.572, 38.162, 38.199, 33.715, 37.242,
        31.910, 37.132, 34.993, 34.660, 41.449, 33.496, 30.781, 34.248, 41.449, 41.907,
        36.081, 41.837, 29.790, 39.617, 39.330, 39.537, 37.586, 37.242, 42.788, 41.160,
        38.960, 38.415, 39.537, 37.845, 35.093, 37.456, 41.449, 39.047, 37.312, 31.545,
        39.537, 37.312, 29.300, 33.683, 41.837, 38.133, 33.683, 42.324, 34.608, 39.347,
        34.192, 41.427, 35.121, 38.960, 32.574, 41.427, 37.242, 38.133, 37.857, 38.162,
        41.427, 34.558, 40.977, 37.586, 29.300, 37.132, 33.998, 32.189, 38.682, 41.907,
        34.660, 29.300, 33.647, 41.000, 42.234, 33.647, 34.635, 42.234, 40.948, 39.018,
        35.121, 40.021, 30.869, 32.189, 42.788, 37.611, 37.990, 38.361, 34.625, 29.790,
        28.363, 34.247, 41.907, 36.081, 31.020, 40.657, 29.790, 37.456, 38.199, 30.869,
        35.615, 30.781, 39.570, 31.910, 35.221, 39.047, 36.858, 40.464, 34.635, 37.611,
        31.910, 39.617, 41.837, 42.234, 37.979, 37.990, 39.347, 37.404, 40.021, 37.519,
        34.558, 42.650, 39.018, 41.775, 38.182, 28.363, 39.047, 37.990, 37.611, 42.324,
        38.415, 39.018, 37.979, 34.625, 38.572, 34.247, 38.361, 30.869, 39.617, 35.093,
        34.660, 34.993, 40.021, 38.199, 39.330, 35.121, 40.977, 37.068, 34.335, 35.093,
        41.160, 42.973, 37.404, 33.496, 37.312, 33.683, 42.650, 33.998, 37.979, 38.415,
        33.530, 37.404, 40.657, 31.545, 43.527, 35.221, 41.775, 34.335, 34.993, 37.132,
        38.682, 36.858, 34.608, 33.998, 40.464, 38.682, 34.248, 40.948, 34.248, 35.615,
        37.845, 32.574, 31.020
    ],
    "predicted": [
        38.682, 34.558, 34.192, 34.660, 31.539, 31.539, 42.973, 34.660, 28.363, 39.570,
        39.570, 37.312, 42.973, 39.617, 32.189, 29.790, 38.162, 33.496, 36.081, 38.133,
        32.189, 39.347, 40.948, 34.635, 34.625, 38.682, 32.574, 30.781, 39.330, 34.335,
        42.650, 33.647, 43.527, 38.182, 32.574, 40.657, 41.160, 41.775, 36.858, 35.121,
        42.234, 42.788, 37.519, 35.221, 37.132, 42.788, 35.221, 31.020, 31.545, 37.068,
        39.659, 37.979, 42.650, 31.539, 39.047, 37.979, 38.182, 40.977, 37.586, 38.960,
        34.625, 42.973, 41.449, 33.715, 35.615, 39.659, 37.586, 38.199, 31.545, 37.242,
        31.910, 37.132, 34.608, 34.660, 41.449, 33.496, 30.781, 33.683, 42.234, 41.907,
        36.081, 40.977, 34.192, 37.611, 39.330, 41.160, 37.586, 37.242, 42.788, 43.527,
        38.960, 38.415, 42.650, 37.845, 33.496, 37.456, 42.234, 39.047, 38.361, 33.715,
        39.537, 39.018, 29.300, 33.683, 41.160, 38.133, 34.248, 42.324, 34.993, 39.347,
        33.998, 42.324, 35.121, 38.960, 33.998, 42.324, 37.242, 38.133, 38.682, 38.162,
        42.324, 34.558, 41.837, 38.162, 30.869, 34.993, 33.998, 37.068, 38.682, 38.960,
        34.660, 29.300, 33.647, 41.000, 41.449, 33.647, 34.635, 41.449, 38.960, 39.018,
        33.530, 39.152, 30.869, 32.189, 42.788, 39.617, 37.990, 37.312, 34.625, 30.781,
        28.363, 34.247, 40.464, 36.081, 31.020, 40.657, 30.781, 37.611, 38.133, 30.869,
        35.615, 30.781, 39.570, 36.081, 35.221, 39.047, 36.858, 40.464, 34.635, 37.611,
        31.910, 37.456, 40.977, 41.000, 37.519, 37.990, 39.347, 37.404, 39.296, 37.519,
        34.558, 42.973, 39.018, 41.775, 38.182, 28.363, 39.047, 37.990, 37.611, 42.324,
        38.415, 39.018, 37.519, 34.247, 39.296, 34.247, 38.361, 30.869, 37.611, 33.496,
        34.625, 34.993, 39.152, 38.199, 39.330, 35.121, 41.449, 32.189, 34.335, 34.635,
        42.650, 42.650, 41.775, 33.496, 38.361, 34.248, 39.537, 33.998, 37.845, 37.857,
        35.121, 37.857, 40.657, 33.715, 42.650, 34.625, 41.775, 34.335, 34.993, 37.132,
        37.857, 38.162, 34.993, 34.192, 40.464, 38.682, 33.683, 40.948, 33.683, 35.615,
        37.845, 32.574, 28.363
    ]
}

df = pd.DataFrame(data)

# Ajustar regresión polinomial (grado 2)
grado = 2
coef_poly = np.polyfit(df['actual'], df['predicted'], grado)
polynomial = np.poly1d(coef_poly)
y_poly_pred = polynomial(df['actual'])

# Calcular R²
ss_res = np.sum((df['predicted'] - y_poly_pred) ** 2)
ss_tot = np.sum((df['predicted'] - np.mean(df['predicted'])) ** 2)
r2_poly = 1 - (ss_res / ss_tot)

# Mostrar R² redondeado a 2 decimales
print(f"{r2_poly:.2f}")
# Gráfico
plt.figure(figsize=(10, 6))

# Puntos 'actual' vs 'predicted'
plt.scatter(df['actual'], df['predicted'], marker='x', color='orange', label='Actual', s=40, alpha=0.6)
plt.scatter(df['actual'], df['actual'], marker='o', color='darkblue', label='Predicted', s=100, alpha=0.8)

# Ajuste polinomial (ordenar para trazar bonito)
x_range = np.linspace(df['actual'].min(), df['actual'].max(), 500)
y_fit = polynomial(x_range)
plt.plot(x_range, y_fit, color='red', linewidth=2, label='Regresion Lineal')

# Añadir línea para R² en verde
plt.plot([], [], color='green', label=f'$R^2$ = {r2_poly:.2f}')

# Estética
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Dispersión Actual vs Predicted con ajuste polinomial')
plt.legend()
plt.grid(True)

# exportar imagen
plt.savefig("FDN_FINISH_10000.png", dpi=500, bbox_inches='tight')  
plt.show()
# Out:
# 0.90

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Tus datos
data = {
    "actual": [
        37.857, 34.558, 32.574, 34.660, 31.539, 31.539, 43.527, 34.625, 28.363, 39.570,
        39.570, 38.361, 41.160, 37.456, 37.068, 30.781, 38.162, 33.496, 36.081, 38.133,
        32.189, 39.347, 40.948, 34.635, 34.660, 37.857, 34.192, 33.715, 39.330, 34.335,
        42.973, 33.647, 42.973, 38.182, 34.192, 40.657, 40.464, 41.775, 36.858, 33.530,
        41.000, 42.324, 37.519, 34.660, 33.530, 42.788, 35.221, 31.020, 33.715, 37.068,
        38.572, 37.845, 43.527, 31.539, 34.608, 37.519, 38.182, 40.977, 37.586, 38.960,
        34.247, 42.650, 41.000, 31.545, 35.615, 38.572, 38.162, 38.199, 33.715, 37.242,
        31.910, 37.132, 34.993, 34.660, 41.449, 33.496, 30.781, 34.248, 41.449, 41.907,
        36.081, 41.837, 29.790, 39.617, 39.330, 39.537, 37.586, 37.242, 42.788, 41.160,
        38.960, 38.415, 39.537, 37.845, 35.093, 37.456, 41.449, 39.047, 37.312, 31.545,
        39.537, 37.312, 29.300, 33.683, 41.837, 38.133, 33.683, 42.324, 34.608, 39.347,
        34.192, 41.427, 35.121, 38.960, 32.574, 41.427, 37.242, 38.133, 37.857, 38.162,
        41.427, 34.558, 40.977, 37.586, 29.300, 37.132, 33.998, 32.189, 38.682, 41.907,
        34.660, 29.300, 33.647, 41.000, 42.234, 33.647, 34.635, 42.234, 40.948, 39.018,
        35.121, 40.021, 30.869, 32.189, 42.788, 37.611, 37.990, 38.361, 34.625, 29.790,
        28.363, 34.247, 41.907, 36.081, 31.020, 40.657, 29.790, 37.456, 38.199, 30.869,
        35.615, 30.781, 39.570, 31.910, 35.221, 39.047, 36.858, 40.464, 34.635, 37.611,
        31.910, 39.617, 41.837, 42.234, 37.979, 37.990, 39.347, 37.404, 40.021, 37.519,
        34.558, 42.650, 39.018, 41.775, 38.182, 28.363, 39.047, 37.990, 37.611, 42.324,
        38.415, 39.018, 37.979, 34.625, 38.572, 34.247, 38.361, 30.869, 39.617, 35.093,
        34.660, 34.993, 40.021, 38.199, 39.330, 35.121, 40.977, 37.068, 34.335, 35.093,
        41.160, 42.973, 37.404, 33.496, 37.312, 33.683, 42.650, 33.998, 37.979, 38.415,
        33.530, 37.404, 40.657, 31.545, 43.527, 35.221, 41.775, 34.335, 34.993, 37.132,
        38.682, 36.858, 34.608, 33.998, 40.464, 38.682, 34.248, 40.948, 34.248, 35.615,
        37.845, 32.574, 31.020
    ],
    "predicted": [
        38.682, 34.558, 34.192, 34.660, 31.539, 31.539, 42.973, 34.660, 28.363, 39.570,
        39.570, 37.312, 42.973, 39.617, 32.189, 29.790, 38.162, 33.496, 36.081, 38.133,
        32.189, 39.347, 40.948, 34.635, 34.625, 38.682, 32.574, 30.781, 39.330, 34.335,
        42.650, 33.647, 43.527, 38.182, 32.574, 40.657, 41.160, 41.775, 36.858, 35.121,
        42.234, 42.788, 37.519, 35.221, 37.132, 42.788, 35.221, 31.020, 31.545, 37.068,
        39.659, 37.979, 42.650, 31.539, 39.047, 37.979, 38.182, 40.977, 37.586, 38.960,
        34.625, 42.973, 41.449, 33.715, 35.615, 39.659, 37.586, 38.199, 31.545, 37.242,
        31.910, 37.132, 34.608, 34.660, 41.449, 33.496, 30.781, 33.683, 42.234, 41.907,
        36.081, 40.977, 34.192, 37.611, 39.330, 41.160, 37.586, 37.242, 42.788, 43.527,
        38.960, 38.415, 42.650, 37.845, 33.496, 37.456, 42.234, 39.047, 38.361, 33.715,
        39.537, 39.018, 29.300, 33.683, 41.160, 38.133, 34.248, 42.324, 34.993, 39.347,
        33.998, 42.324, 35.121, 38.960, 33.998, 42.324, 37.242, 38.133, 38.682, 38.162,
        42.324, 34.558, 41.837, 38.162, 30.869, 34.993, 33.998, 37.068, 38.682, 38.960,
        34.660, 29.300, 33.647, 41.000, 41.449, 33.647, 34.635, 41.449, 38.960, 39.018,
        33.530, 39.152, 30.869, 32.189, 42.788, 39.617, 37.990, 37.312, 34.625, 30.781,
        28.363, 34.247, 40.464, 36.081, 31.020, 40.657, 30.781, 37.611, 38.133, 30.869,
        35.615, 30.781, 39.570, 36.081, 35.221, 39.047, 36.858, 40.464, 34.635, 37.611,
        31.910, 37.456, 40.977, 41.000, 37.519, 37.990, 39.347, 37.404, 39.296, 37.519,
        34.558, 42.973, 39.018, 41.775, 38.182, 28.363, 39.047, 37.990, 37.611, 42.324,
        38.415, 39.018, 37.519, 34.247, 39.296, 34.247, 38.361, 30.869, 37.611, 33.496,
        34.625, 34.993, 39.152, 38.199, 39.330, 35.121, 41.449, 32.189, 34.335, 34.635,
        42.650, 42.650, 41.775, 33.496, 38.361, 34.248, 39.537, 33.998, 37.845, 37.857,
        35.121, 37.857, 40.657, 33.715, 42.650, 34.625, 41.775, 34.335, 34.993, 37.132,
        37.857, 38.162, 34.993, 34.192, 40.464, 38.682, 33.683, 40.948, 33.683, 35.615,
        37.845, 32.574, 28.363
    ]
}

df = pd.DataFrame(data)

df = pd.DataFrame(data)

# Ajustar regresión polinomial (grado 2)
grado = 2
coef_poly = np.polyfit(df['actual'], df['predicted'], grado)
polynomial = np.poly1d(coef_poly)
y_poly_pred = polynomial(df['actual'])

# Calcular R²
ss_res = np.sum((df['predicted'] - y_poly_pred) ** 2)
ss_tot = np.sum((df['predicted'] - np.mean(df['predicted'])) ** 2)
r2_poly = 1 - (ss_res / ss_tot)

# Calcular Error Absoluto Medio (MAE)
mae = np.mean(np.abs(df['predicted'] - df['actual']))

print(f"R² del modelo: {r2_poly:.2f}")
print(f"Error Absoluto Medio (MAE): {mae:.2f}")

# Gráfico
plt.figure(figsize=(12, 7))

# Puntos de datos
sns.scatterplot(x='actual', y='predicted', data=df, color='orange', label='Predicted', marker='x', s=40, alpha=0.6)
sns.scatterplot(x='actual', y='actual', data=df, color='deepskyblue', label='Actual', marker='o', s=100, alpha=0.8)

# Ajuste polinomial
x_range = np.linspace(df['actual'].min(), df['actual'].max(), 500)
y_fit = polynomial(x_range)
plt.plot(x_range, y_fit, color='red', linewidth=2, label='Polynomial fit')

# Texto con R² y MAE
plt.text(df['actual'].min(), df['predicted'].max(), f'$R^2$ = {r2_poly:.2f}\nMAE = {mae:.2f}', 
         fontsize=12, color='green', bbox=dict(facecolor='white', alpha=0.5))

# Estética
plt.title('Dispersión Actual vs Predicted con Ajuste Polinomial\nIncluyendo Error Absoluto Medio (MAE)', fontsize=16)
plt.xlabel('Actual', fontsize=14)
plt.ylabel('Predicted', fontsize=14)
plt.legend()
plt.grid(True)

# Exportar imagen
plt.savefig("FDN_FINISH_002.png", dpi=500, bbox_inches='tight')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# R² del modelo: 0.90
# Error Absoluto Medio (MAE): 0.61

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#
        38.960, 38.415, 42.650, 37.845, 33.496, 37.456, 42.234, 39.047, 38.361, 33.715,
        39.537, 39.018, 29.300, 33.683, 41.160, 38.133, 34.248, 42.324, 34.993, 39.347,
        33.998, 42.324, 35.121, 38.960, 33.998, 42.324, 37.242, 38.133, 38.682, 38.162,
        42.324, 34.558, 41.837, 38.162, 30.869, 34.993, 33.998, 37.068, 38.682, 38.960,
        34.660, 29.300, 33.647, 41.000, 41.449, 33.647, 34.635, 41.449, 38.960, 39.018,
        33.530, 39.152, 30.869, 32.189, 42.788, 39.617, 37.990, 37.312, 34.625, 30.781,
        28.363, 34.247, 40.464, 36.081, 31.020, 40.657, 30.781, 37.611, 38.133, 30.869,
        35.615, 30.781, 39.570, 36.081, 35.221, 39.047, 36.858, 40.464, 34.635, 37.611,
        31.910, 37.456, 40.977, 41.000, 37.519, 37.990, 39.347, 37.404, 39.296, 37.519,
        34.558, 42.973, 39.018, 41.775, 38.182, 28.363, 39.047, 37.990, 37.611, 42.324,
        38.415, 39.018, 37.519, 34.247, 39.296, 34.247, 38.361, 30.869, 37.611, 33.496,
        34.625, 34.993, 39.152, 38.199, 39.330, 35.121, 41.449, 32.189, 34.335, 34.635,
        42.650, 42.650, 41.775, 33.496, 38.361, 34.248, 39.537, 33.998, 37.845, 37.857,
        35.121, 37.857, 40.657, 33.715, 42.650, 34.625, 41.775, 34.335, 34.993, 37.132,
        37.857, 38.162, 34.993, 34.192, 40.464, 38.682, 33.683, 40.948, 33.683, 35.615,
        37.845, 32.574, 28.363
    ]
}

df = pd.DataFrame(data)
# Ajustar regresión polinomial (grado 2)
grado = 2
coef_poly = np.polyfit(df['actual'], df['predicted'], grado)
polynomial = np.poly1d(coef_poly)
y_poly_pred = polynomial(df['actual'])

# Calcular R²
ss_res = np.sum((df['predicted'] - y_poly_pred) ** 2)
ss_tot = np.sum((df['predicted'] - np.mean(df['predicted'])) ** 2)
r2_poly = 1 - (ss_res / ss_tot)

# Calcular MAE y RMSE
mae = np.mean(np.abs(df['predicted'] - df['actual']))
rmse = np.sqrt(np.mean((df['predicted'] - df['actual'])**2))

# Mostrar resultados
print(f"R2: {r2_poly:.2f}")
print(f"MAE: {mae:.2f}")
print(f"RMSE: {rmse:.2f}")

# Gráfico
plt.figure(figsize=(10, 6))

# Puntos 'actual' vs 'predicted'
plt.scatter(df['actual'], df['predicted'], marker='x', color='orange', label='Actual', s=40, alpha=0.6)
plt.scatter(df['actual'], df['actual'], marker='o', color='darkblue', label='Predicted', s=100, alpha=0.8)

# Ajuste polinomial
x_range = np.linspace(df['actual'].min(), df['actual'].max(), 500)
y_fit = polynomial(x_range)
plt.plot(x_range, y_fit, color='red', linewidth=2, label='Regresión Lineal')

# Líneas invisibles para estadísticas
plt.plot([], [], color='green', label=f'$R^2$ = {r2_poly:.2f}')
plt.plot([], [], color='purple', label=f'MAE = {mae:.2f}')
plt.plot([], [], color='blue', label=f'RMSE = {rmse:.2f}')

# Estética
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Dispersión Actual vs Predicted con ajuste polinomial')
plt.legend()
plt.grid(True)

# Exportar imagen
plt.savefig("FDN_FINISH_10000.png", dpi=500, bbox_inches='tight')
plt.show()
# Out:
# R2: 0.90
# MAE: 0.61
# RMSE: 1.18

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

# --- Datos ya cargados en df ---

# Calcular errores
df["absolute_error"] = abs(df["actual"] - df["predicted"])
mae = df["absolute_error"].mean()

df["squared_error"] = (df["actual"] - df["predicted"])**2
rmse = np.sqrt(df["squared_error"].mean())

# Cálculo de la regresión
coef = np.polyfit(df["actual"], df["predicted"], deg=1)
poly1d_fn = np.poly1d(coef)

# Cálculo de R²
correlation_matrix = np.corrcoef(df["actual"], df["predicted"])
correlation_xy = correlation_matrix[0, 1]
r_squared = correlation_xy ** 2

# Gráfica
plt.figure(figsize=(10, 6))

# Scatter plot
plt.scatter(df["actual"], df["predicted"], label="Predicted", marker="v", color="orange", s=40, alpha=0.8)
plt.scatter(df["actual"], df["actual"], label="Actual", marker="o", color="darkblue", s=40, alpha=0.8)

# Línea de regresión
x_vals = np.linspace(df["actual"].min(), df["actual"].max(), 100)
plt.plot(x_vals, poly1d_fn(x_vals), color="red", label="Regresión")

# Crear líneas falsas para la leyenda de los errores y R²
mae_label = mlines.Line2D([], [], color='purple', marker='', linestyle='None', label=f"MAE = {mae:.2f}")
rmse_label = mlines.Line2D([], [], color='blue', marker='', linestyle='None', label=f"RMSE = {rmse:.2f}")
r2_label = mlines.Line2D([], [], color='green', marker='', linestyle='None', label=f"$R^2$ = {r_squared:.2f}")

# Leyenda completa
legend = plt.legend(handles=[
    plt.Line2D([], [], color='orange', marker='v', linestyle='None', markersize=8, label='Actual'),
    plt.Line2D([], [], color='darkblue', marker='o', linestyle='None', markersize=8, label='Predicted by Model'),
    plt.Line2D([], [], color='red', linestyle='-', label='Regresión'),
    mae_label,
    rmse_label,
    r2_label
], frameon=True, loc="upper left")

# Cambiar color de textos de los errores y R²
legend_texts = legend.get_texts()
legend_texts[-3].set_color("purple")  # MAE
legend_texts[-2].set_color("blue")    # RMSE
legend_texts[-1].set_color("green")   # R²

# Etiquetas y título
plt.title('Proteína')
plt.xlabel('Valor Bromatológico')
plt.ylabel('Valor Predicho')
plt.grid(True)
plt.tight_layout()
plt.savefig("FDN_HOMERO_100.png", dpi=500, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

# --- Datos ya cargados en df ---

# Calcular errores
df["absolute_error"] = abs(df["actual"] - df["predicted"])
mae = df["absolute_error"].mean()

df["squared_error"] = (df["actual"] - df["predicted"])**2
rmse = np.sqrt(df["squared_error"].mean())

# Cálculo de la regresión
coef = np.polyfit(df["actual"], df["predicted"], deg=1)
poly1d_fn = np.poly1d(coef)

# Cálculo de R²
correlation_matrix = np.corrcoef(df["actual"], df["predicted"])
correlation_xy = correlation_matrix[0, 1]
r_squared = correlation_xy ** 2

# Gráfica
plt.figure(figsize=(10, 6))

# Scatter plot
plt.scatter(df["actual"], df["predicted"], label="Predicted", marker="v", color="orange", s=40, alpha=0.8)
plt.scatter(df["actual"], df["actual"], label="Actual", marker="o", color="darkblue", s=40, alpha=0.8)

# Línea de regresión
x_vals = np.linspace(df["actual"].min(), df["actual"].max(), 100)
plt.plot(x_vals, poly1d_fn(x_vals), color="red", label="Regresión")

# Crear líneas falsas para la leyenda de los errores y R²
mae_label = mlines.Line2D([], [], color='purple', marker='', linestyle='None', label=f"MAE = {mae:.2f}")
rmse_label = mlines.Line2D([], [], color='blue', marker='', linestyle='None', label=f"RMSE = {rmse:.2f}")
r2_label = mlines.Line2D([], [], color='green', marker='', linestyle='None', label=f"$R^2$ = {r_squared:.2f}")

# Leyenda completa
legend = plt.legend(handles=[
    plt.Line2D([], [], color='red', linestyle='-', label='Regresión'),
    mae_label,
    rmse_label,
    r2_label
], frameon=True, loc="upper left")

# Cambiar color de textos de los errores y R²
legend_texts = legend.get_texts()
legend_texts[-3].set_color("purple")  # MAE
legend_texts[-2].set_color("blue")    # RMSE
legend_texts[-1].set_color("green")   # R²

# Etiquetas y título
plt.title('FDN')
plt.xlabel('Valor Bromatológico')
plt.ylabel('Valor Predicho')
plt.grid(True)
plt.tight_layout()
plt.savefig("FDN_HOMERO_100.png", dpi=500, bbox_inches='tight')
plt.show()

# %%
cd Escritorio/homero/homero/
# Out:
# /home/marcos/Escritorio/homero/homero
# /home/marcos/.local/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
