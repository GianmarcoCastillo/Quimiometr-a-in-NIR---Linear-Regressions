# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
cd marcos/Escritorio/homero/homero/
# Out:
# [Errno 2] No such file or directory: 'marcos/Escritorio/homero/homero/'
# /home/marcos/Descargas
# /home/marcos/.local/lib/python3.10/site-packages/IPython/core/magics/osm.py:393: UserWarning: This is now an optional IPython functionality, using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})

# %%
ls
# Out:
# '0 PC2 - BA - 20078 APLICADO miércoles 23octubre 2024.docx'
#  001_best_spades_graph.gfa
#  004-2024-INFORME-PAGO-CIF-PMRG.pdf
#  02_Instalando_CarveMe.pdf
#  02_StochasticMolecules.pdf
#  03_MolecularDynamics.pdf
#  04_EnhancedMD.pdf
#  05_MarkovSM.pdf
# '09 Linkin Park - Breaking The Habit - ElNinjaDeVenezuela.mp3'
#  0Cb1Hv8q.jpeg
# '1. 3 FICHA DE PERSONAL - FIBERLINE - TERMINADO.pdf'
# '10. Docking Molecular.pdf'
#  10.1007_978-1-4614-5882-1_3-citation.ris
# '10-11. Docking Molecular-1.pdf'
# '10-11. Docking Molecular.pdf'
#  1085247861.2013.pdf
# '10.+Indefinite+Articles+(A1-A2)-1.pdf'
# '11. Topicos MDB. Modeller.pdf'
# '11.+Verb+to+like+-+Colors+(A1-A2).pdf'
# '12. Topicos MDB. Modeller-1.pdf'
# '12. Topicos MDB. Modeller.pdf'
#  125978280-1.pdf
#  125978280.pdf
#  1277881.seq1.eps
#  12870_2024_5513_MOESM1_ESM.docx
# '12.+Phonetics+D+(A1-A2).pdf'
# '13. Topicos MDB. Epitopos (Diego Rivas).pdf'
# '13.+Nouns+(A1-A2).pdf'
# '13.+The+Plural+of+nouns+(A1-A2).pdf'
# ...

# %%
data = {
    'actual': [
        12.775, 16.713, 21.892, 19.688, 21.35, 21.35, 15.377, 19.228, 20.606, 10.628, 
        10.628, 9.778, 15.619, 10.806, 15.028, 21.263, 15.269, 17.653, 20.147, 10.762, 
        21.866, 11.266, 15.925, 14.782, 19.688, 12.775, 21.722, 21.088, 11.675, 17.126, 
        13.891, 21.284, 13.891, 11.178, 21.722, 14.831, 14.722, 15.838, 17.981, 18.244, 
        10.238, 9.231, 17.608, 19.688, 18.244, 11.288, 19.403, 19.598, 21.088, 15.028,
        11.463, 15.663, 15.377, 21.35, 19.95, 17.608, 11.178, 9.121, 17.892, 14.459,
        19.6, 14.26, 10.238, 20.059, 18.134, 11.463, 15.269, 11.134, 21.088, 12.512,
        22.072, 19.534, 20.539, 19.688, 10.894, 17.653, 21.263, 17.15, 10.894, 14.175,
        20.147, 9.467, 20.823, 11.397, 11.675, 10.259, 17.892, 12.512, 11.288, 15.619,
        14.459, 16.909, 10.259, 15.663, 17.675, 10.806, 10.894, 15.794, 10.566, 20.059,
        10.259, 10.566, 19.338, 17.697, 9.467, 10.762, 17.697, 9.231, 19.95, 11.266,
        21.722, 10.407, 18.309, 14.459, 21.892, 10.407, 12.512, 10.762, 12.775, 15.269,
        10.407, 16.713, 9.121, 17.892, 19.338, 19.534, 19.381, 21.866, 11.002, 14.175,
        19.688, 19.338, 21.284, 10.238, 10.627, 21.284, 14.782, 10.627, 15.925, 11.025,
        18.309, 11.069, 21.562, 21.866, 11.288, 11.655, 11.347, 9.778, 19.228, 20.823,
        20.606, 19.6, 14.175, 20.147, 19.598, 14.831, 20.823, 10.806, 11.134, 21.562,
        18.134, 21.263, 10.628, 22.072, 19.403, 15.794, 17.981, 14.722, 14.782, 11.655,

plt.ylabel('Predicted')
plt.grid(True)
plt.show()

# %%
df.columns = df.columns.str.strip()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Supongamos que tu DataFrame ya se llama df y tiene las columnas 'actual' y 'predicted'

plt.figure(figsize=(10,7))
sns.scatterplot(x='actual', y='predicted', data=df)

# Ajustar la recta de regresión
coef = np.polyfit(df['actual'], df['predicted'], 1)
poly1d_fn = np.poly1d(coef)

# Dibujar la línea de regresión
x = np.linspace(df['actual'].min(), df['actual'].max(), 100)
plt.plot(x, poly1d_fn(x), color='red', label=f'Regresión Lineal\n(y={coef[0]:.2f}x+{coef[1]:.2f})')

plt.title('Actual vs Predicted')
plt.xlabel('Proteína')
plt.ylabel('Predicción')
plt.legend()
plt.grid(True)
plt.show()

# %%
df.columns = df.columns.str.strip()

plt.figure(figsize=(10,7))
plt.scatter(df['actual'], df['predicted'], marker='x', color='blue', label='Datos (Actual vs Predicted)')
plt.scatter(df['actual'], df['actual'], marker='v', color='green', label='Actual vs Actual')  # Opcional: mostrar línea ideal

coef = np.polyfit(df['actual'], df['predicted'], 1)
poly1d_fn = np.poly1d(coef)

x = np.linspace(df['actual'].min(), df['actual'].max(), 100)
plt.plot(x, poly1d_fn(x), color='red', label=f'Regresión Lineal\n(y={coef[0]:.2f}x+{coef[1]:.2f})')

plt.title('Actual vs Predicted')
plt.xlabel('Proteína')
plt.ylabel('Predicción')
plt.legend()
plt.grid(True)
plt.show()

# %%
df.columns = df.columns.str.strip()

plt.figure(figsize=(10,7))

plt.scatter(df['actual'], df['actual'], marker='o', color='green', label='Ideal (Actual vs Actual)')

plt.scatter(df['actual'], df['predicted'], marker='x', color='blue', label='Predicted')

coef = np.polyfit(df['actual'], df['predicted'], 1)
poly1d_fn = np.poly1d(coef)

x = np.linspace(df['actual'].min(), df['actual'].max(), 100)
plt.plot(x, poly1d_fn(x), color='red', label=f'Regresión Lineal\n(y={coef[0]:.2f}x+{coef[1]:.2f})')

# Estilo del gráfico
plt.title('Actual vs Predicted')
plt.xlabel('Proteína (Actual)')
plt.ylabel('Predicción')
plt.legend()
plt.grid(True)
plt.show()

# %%
df.columns = df.columns.str.strip()
plt.figure(figsize=(10,7))

plt.scatter(df['actual'], df['actual'], marker='v', color='green', label='Ideal (Actual vs Actual)')

plt.scatter(df['actual'], df['predicted'], marker='x', color='mediumpurple', label='Predicted')

coef = np.polyfit(df['actual'], df['predicted'], 1)
poly1d_fn = np.poly1d(coef)

x = np.linspace(df['actual'].min(), df['actual'].max(), 100)
plt.plot(x, poly1d_fn(x), color='red', label=f'Regresión Lineal\n(y={coef[0]:.2f}x+{coef[1]:.2f})')

plt.title('Actual vs Predicted')
plt.xlabel('Proteína (Actual)')
plt.ylabel('Predicción')
plt.legend()
plt.grid(True)

plt.savefig('actual_vs_predicted.png', dpi=300, bbox_inches='tight')  # <-- Aquí exportas la figura
plt.show()

# %%
df.columns = df.columns.str.strip()
plt.figure(figsize=(10,7))
plt.scatter(df['actual'], df['actual'], marker='x', color='blue', s=80, label='Ideal (Actual vs Actual)')
plt.scatter(df['actual'], df['predicted'], marker='v', color='orange', s=80, label='Predicted')
coef = np.polyfit(df['actual'], df['predicted'], 1)
poly1d_fn = np.poly1d(coef)
x = np.linspace(df['actual'].min(), df['actual'].max(), 100)
plt.plot(x, poly1d_fn(x), color='black', linewidth=2.5, label=f'Regresión Lineal\n(y={coef[0]:.2f}x+{coef[1]:.2f})')
plt.title('Actual vs Predicted', fontsize=16)
plt.xlabel('Proteína (Actual)', fontsize=14)
plt.ylabel('Valor Predicho', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)
# Exportar la imagen
plt.savefig('actual_vs_predicted100.png', dpi=500, bbox_inches='tight')  # <-- Guarda la figura en alta calidad
plt.show()

# %%
df.columns = df.columns.str.strip()
plt.figure(figsize=(10,7))
plt.scatter(df['actual'], df['actual'], marker='o', color='skyblue', s=100, label='Ideal (Actual vs Actual)')
plt.scatter(df['actual'], df['predicted'], marker='x', color='orange', s=40, label='Predicted')
coef = np.polyfit(df['actual'], df['predicted'], 1)
poly1d_fn = np.poly1d(coef)
x = np.linspace(df['actual'].min(), df['actual'].max(), 100)
plt.plot(x, poly1d_fn(x), color='red', linewidth=2.5, label=f'Regresión Lineal\n(y={coef[0]:.2f}x+{coef[1]:.2f})')
plt.title('Actual vs Predicted', fontsize=16)
plt.xlabel('Proteína (Actual)', fontsize=14)
plt.ylabel('Valor Predicho', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)
plt.savefig('actual_vs_predicted100.png', dpi=500, bbox_inches='tight')  # Guarda en alta resolución
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score

df.columns = df.columns.str.strip()

plt.figure(figsize=(10,7))

plt.scatter(df['actual'], df['actual'], marker='x', color='blue', s=100, label='Ideal (Actual vs Actual)')

plt.scatter(df['actual'], df['predicted'], marker='v', color='orange', s=40, label='Predicted')

coef = np.polyfit(df['actual'], df['predicted'], 1)
poly1d_fn = np.poly1d(coef)

x = np.linspace(df['actual'].min(), df['actual'].max(), 100)
plt.plot(x, poly1d_fn(x), color='black', linewidth=2.5, label=f'Regresión Lineal\n(y={coef[0]:.2f}x+{coef[1]:.2f})')

# Calcular R^2
r2 = r2_score(df['actual'], df['predicted'])

# Mostrar R^2 en el gráfico
plt.text(0.05, 0.95, f'$R^2$ = {r2:.3f}', transform=plt.gca().transAxes,
         fontsize=14, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

plt.title('Actual vs Predicted', fontsize=16)
plt.xlabel('Proteína (Actual)', fontsize=14)
plt.ylabel('Valor Predicho', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)

# Exportar la imagen
plt.savefig('actual_vs_predicted100.png', dpi=500, bbox_inches='tight')  # Guarda en alta resolución
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score
df.columns = df.columns.str.strip()
plt.figure(figsize=(10,7))
plt.scatter(df['actual'], df['actual'], marker='o', color='skyblue', s=100, label='Reales')
plt.scatter(df['actual'], df['predicted'], marker='v', color='orange', s=40, label='Predicted')
coef = np.polyfit(df['actual'], df['predicted'], 1)
poly1d_fn = np.poly1d(coef)
r2 = r2_score(df['actual'], df['predicted'])
x = np.linspace(df['actual'].min(), df['actual'].max(), 100)
plt.plot(x, poly1d_fn(x), color='red', linewidth=2.5, label=f'Regresión Lineal\n$R^2$ = {r2:.3f}\n(y={coef[0]:.2f}x+{coef[1]:.2f})')
plt.title('Actual vs Predicted', fontsize=16)
plt.xlabel('Proteína (Actual)', fontsize=14)
plt.ylabel('Valor Predicho', fontsize=14)
plt.legend(fontsize=12, loc='best', frameon=True, shadow=True)  # Mejorar visibilidad de la leyenda
plt.grid(True)
plt.savefig('actual_vs_predicted0_Finish.png', dpi=500, bbox_inches='tight')  # Guarda en alta resolución
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score

df.columns = df.columns.str.strip()

plt.figure(figsize=(10,7))

plt.scatter(df['actual'], df['actual'], marker='o', color='darkblue', s=100, label='Actual')

plt.scatter(df['actual'], df['predicted'], marker='v', color='orange', s=40, label='Predicted')

coef = np.polyfit(df['actual'], df['predicted'], 1)
poly1d_fn = np.poly1d(coef)

r2 = r2_score(df['actual'], df['predicted'])

x = np.linspace(df['actual'].min(), df['actual'].max(), 100)
plt.plot(x, poly1d_fn(x), color='red', linewidth=2.5, label=f'Regresión Lineal\n$R^2$ = {r2:.2f}\n(y={coef[0]:.2f}x+{coef[1]:.2f})')

plt.title('Regresion Lineal Actual vs Predicted', fontsize=16)
plt.xlabel('Proteína (Actual)', fontsize=14)
plt.ylabel('Valor Predicho', fontsize=14)
plt.legend(fontsize=12, loc='best', frameon=True, shadow=True)  # Mejorar visibilidad de la leyenda
plt.grid(True)
# Exportar la imagen
plt.savefig('PROTEINA_Finish_10000.png', dpi=500, bbox_inches='tight')  # Guarda en alta resolución
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score

df.columns = df.columns.str.strip()

plt.figure(figsize=(10,7))

plt.scatter(df['actual'], df['actual'], marker='o', color='darkblue', s=100, label='Actual')

plt.scatter(df['actual'], df['predicted'], marker='v', color='orange', s=40, label='Predicted')

coef = np.polyfit(df['actual'], df['predicted'], 1)
poly1d_fn = np.poly1d(coef)

r2 = r2_score(df['actual'], df['predicted'])

x = np.linspace(df['actual'].min(), df['actual'].max(), 100)
plt.plot(x, poly1d_fn(x), color='red', linewidth=2.5, label=f'Regresión Lineal\n$R^2$ = {r2:.2f}')

plt.title('Regresión Lineal Actual vs Predicted', fontsize=16)
plt.xlabel('Proteína (Actual)', fontsize=14)
plt.ylabel('Valor Predicho', fontsize=14)
plt.legend(fontsize=12, loc='best', frameon=True, shadow=True)
plt.grid(True)

plt.savefig('PROTEINA_Finish_10000.png', dpi=500, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.lines as mlines 

coef = np.polyfit(df["actual"], df["predicted"], deg=1)
poly1d_fn = np.poly1d(coef)

correlation_matrix = np.corrcoef(df["actual"], df["predicted"])
correlation_xy = correlation_matrix[0, 1]
r_squared = correlation_xy ** 2

plt.figure(figsize=(10, 6))

plt.scatter(df["actual"], df["predicted"], label="Predicted", marker="o", color="blue", s=40, alpha=0.8)
plt.scatter(df["actual"], df["actual"], label="Actual", marker="x", color="black", s=40, alpha=0.8)

x_vals = np.linspace(df["actual"].min(), df["actual"].max(), 100)
plt.plot(x_vals, poly1d_fn(x_vals), color="red", label="Regresión")

r2_label = mlines.Line2D([], [], color='green', marker='', linestyle='None', 
                         label=f"$R^2$ = {r_squared:.2f}")


plt.legend(handles=[  
    plt.Line2D([], [], color='blue', marker='o', linestyle='None', markersize=8, label='Predicted'),
    plt.Line2D([], [], color='black', marker='x', linestyle='None', markersize=8, label='Actual'),
    plt.Line2D([], [], color='red', linestyle='-', label='Regresión'),
    r2_label 
], frameon=True, loc="upper left")

plt.title('Actual vs Predicted')
plt.xlabel('Valor Actual')
plt.ylabel('Valor Predicho')
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.lines as mlines  

coef = np.polyfit(df["actual"], df["predicted"], deg=1)
poly1d_fn = np.poly1d(coef)

correlation_matrix = np.corrcoef(df["actual"], df["predicted"])
correlation_xy = correlation_matrix[0, 1]
r_squared = correlation_xy ** 2

plt.figure(figsize=(10, 6))

plt.scatter(df["actual"], df["predicted"], label="Predicted", marker="v", color="orange", s=40, alpha=0.8)
plt.scatter(df["actual"], df["actual"], label="Actual", marker="o", color="darkblue", s=40, alpha=0.8)

x_vals = np.linspace(df["actual"].min(), df["actual"].max(), 100)
plt.plot(x_vals, poly1d_fn(x_vals), color="red", label="Regresión")

r2_label = mlines.Line2D([], [], color='green', marker='', linestyle='None', label=f"$R^2$ = {r_squared:.2f}")

legend = plt.legend(handles=[
    plt.Line2D([], [], color='orange', marker='v', linestyle='None', markersize=8, label='Predicted'),
    plt.Line2D([], [], color='darkblue', marker='o', linestyle='None', markersize=8, label='Actual'),
    plt.Line2D([], [], color='red', linestyle='-', label='Regresión'),
    r2_label
], frameon=True, loc="upper left")

legend_texts = legend.get_texts()
legend_texts[-1].set_color("green")  # el último texto es el del R²

# Etiquetas y título
plt.title('Proteina')
plt.xlabel('Valor Bromatologico')
plt.ylabel('Valor Predicho')
plt.grid(True)
plt.tight_layout()
plt.savefig("PROTEINA_FINISH_10000.png", dpi=500, bbox_inches='tight')  
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.lines as mlines  # para crear líneas falsas

coef = np.polyfit(df["actual"], df["predicted"], deg=1)
poly1d_fn = np.poly1d(coef)

correlation_matrix = np.corrcoef(df["actual"], df["predicted"])
correlation_xy = correlation_matrix[0, 1]
r_squared = correlation_xy ** 2

plt.figure(figsize=(10, 6))

plt.scatter(df["actual"], df["predicted"], label="Predicted", marker="v", color="orange", s=40, alpha=0.8)
plt.scatter(df["actual"], df["actual"], label="Actual", marker="o", color="darkblue", s=40, alpha=0.8)

x_vals = np.linspace(df["actual"].min(), df["actual"].max(), 100)
plt.plot(x_vals, poly1d_fn(x_vals), color="red", label="Regresión")

r2_label = mlines.Line2D([], [], color='green', marker='', linestyle='None', label=f"$R^2$ = {r_squared:.2f}")

legend = plt.legend(handles=[
    plt.Line2D([], [], color='orange', marker='v', linestyle='None', markersize=8, label='Actual'),
    plt.Line2D([], [], color='darkblue', marker='o', linestyle='None', markersize=8, label='Predicted by Model'),
    plt.Line2D([], [], color='red', linestyle='-', label='Regresión'),
    r2_label
], frameon=True, loc="upper left")

legend_texts = legend.get_texts()
legend_texts[-1].set_color("green")  # el último texto es el del R²

plt.title('Proteina')
plt.xlabel('Valor Bromatologico')
plt.ylabel('Valor Predicho')
plt.grid(True)
plt.tight_layout()
plt.savefig("PROTEINA_FINISH_10000.png", dpi=500, bbox_inches='tight')  
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.lines as mlines 

coef = np.polyfit(df["actual"], df["predicted"], deg=1)
poly1d_fn = np.poly1d(coef)

correlation_matrix = np.corrcoef(df["actual"], df["predicted"])
correlation_xy = correlation_matrix[0, 1]
r_squared = correlation_xy ** 2

mae = np.mean(np.abs(df["predicted"] - df["actual"]))
print(f"Error Absoluto Medio (MAE): {mae:.4f}")

plt.figure(figsize=(10, 6))

plt.scatter(df["actual"], df["predicted"], label="Predicted", marker="v", color="orange", s=40, alpha=0.8)
plt.scatter(df["actual"], df["actual"], label="Actual", marker="o", color="darkblue", s=40, alpha=0.8)


x_vals = np.linspace(df["actual"].min(), df["actual"].max(), 100)
plt.plot(x_vals, poly1d_fn(x_vals), color="red", label="Regresión")

r2_label = mlines.Line2D([], [], color='green', marker='', linestyle='None', label=f"$R^2$ = {r_squared:.2f}")

mae_label = mlines.Line2D([], [], color='purple', marker='', linestyle='None', label=f"MAE = {mae:.2f}")

legend = plt.legend(handles=[
    plt.Line2D([], [], color='orange', marker='v', linestyle='None', markersize=8, label='Actual'),
    plt.Line2D([], [], color='darkblue', marker='o', linestyle='None', markersize=8, label='Predicted by Model'),
    plt.Line2D([], [], color='red', linestyle='-', label='Regresión'),
    r2_label,
    mae_label
], frameon=True, loc="upper left")

legend_texts = legend.get_texts()
legend_texts[-2].set_color("green")  # penúltimo texto es el del R²
legend_texts[-1].set_color("purple")  # último texto es el del MAE

plt.title('Proteína')
plt.xlabel('Valor Bromatológico')
plt.ylabel('Valor Predicho')
plt.grid(True)
plt.tight_layout()
plt.savefig("PROTEINA_FINISH_20000.png", dpi=500, bbox_inches='tight')  
plt.show()
# Out:
# Error Absoluto Medio (MAE): 0.5708

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.lines as mlines 
coef = np.polyfit(df["actual"], df["predicted"], deg=1)
poly1d_fn = np.poly1d(coef)

correlation_matrix = np.corrcoef(df["actual"], df["predicted"])
correlation_xy = correlation_matrix[0, 1]
r_squared = correlation_xy ** 2

mae = np.mean(np.abs(df["actual"] - df["predicted"]))
rmse = np.sqrt(np.mean((df["actual"] - df["predicted"])**2))

plt.figure(figsize=(10, 6))

plt.scatter(df["actual"], df["predicted"], label="Predicted", marker="v", color="orange", s=40, alpha=0.8)
plt.scatter(df["actual"], df["actual"], label="Actual", marker="o", color="darkblue", s=40, alpha=0.8)

x_vals = np.linspace(df["actual"].min(), df["actual"].max(), 100)
plt.plot(x_vals, poly1d_fn(x_vals), color="red", label="Regresión")

mae_label = mlines.Line2D([], [], color='purple', marker='', linestyle='None', label=f"MAE = {mae:.2f}")
rmse_label = mlines.Line2D([], [], color='blue', marker='', linestyle='None', label=f"RMSE = {rmse:.2f}")
r2_label = mlines.Line2D([], [], color='green', marker='', linestyle='None', label=f"$R^2$ = {r_squared:.2f}")

legend = plt.legend(handles=[
    plt.Line2D([], [], color='orange', marker='v', linestyle='None', markersize=8, label='Actual'),
    plt.Line2D([], [], color='darkblue', marker='o', linestyle='None', markersize=8, label='Predicted by Model'),
    plt.Line2D([], [], color='red', linestyle='-', label='Regresión'),
    mae_label,
    rmse_label,
    r2_label
], frameon=True, loc="upper left")

legend_texts = legend.get_texts()
legend_texts[-3].set_color("purple")  # MAE
legend_texts[-2].set_color("blue")    # RMSE
legend_texts[-1].set_color("green")   # R²

plt.title('Proteína')
plt.xlabel('Valor Bromatológico')
plt.ylabel('Valor Predicho')
plt.grid(True)
plt.tight_layout()
plt.savefig("PROTEINA_FINISH_CHAMO_10000.png", dpi=500, bbox_inches='tight')  
plt.show()

# %%
cd Escritorio/homero/homero/
# Out:
# /home/marcos/Escritorio/homero/homero
# /home/marcos/.local/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.lines as mlines 
coef = np.polyfit(df["actual"], df["predicted"], deg=1)
poly1d_fn = np.poly1d(coef)

correlation_matrix = np.corrcoef(df["actual"], df["predicted"])
correlation_xy = correlation_matrix[0, 1]
r_squared = correlation_xy ** 2

mae = np.mean(np.abs(df["actual"] - df["predicted"]))
rmse = np.sqrt(np.mean((df["actual"] - df["predicted"])**2))

plt.figure(figsize=(10, 6))

plt.scatter(df["actual"], df["predicted"], label="Predicted", marker="v", color="orange", s=40, alpha=0.8)
plt.scatter(df["actual"], df["actual"], label="Actual", marker="o", color="darkblue", s=40, alpha=0.8)

x_vals = np.linspace(df["actual"].min(), df["actual"].max(), 100)
plt.plot(x_vals, poly1d_fn(x_vals), color="red", label="Regresión")

mae_label = mlines.Line2D([], [], color='purple', marker='', linestyle='None', label=f"MAE = {mae:.2f}")
rmse_label = mlines.Line2D([], [], color='blue', marker='', linestyle='None', label=f"RMSE = {rmse:.2f}")
r2_label = mlines.Line2D([], [], color='green', marker='', linestyle='None', label=f"$R^2$ = {r_squared:.2f}")

legend = plt.legend(handles=[
    plt.Line2D([], [], color='red', linestyle='-', label='Regresión'),
    mae_label,
    rmse_label,
    r2_label
], frameon=True, loc="upper left")

legend_texts = legend.get_texts()
legend_texts[-3].set_color("purple")  # MAE
legend_texts[-2].set_color("blue")    # RMSE
legend_texts[-1].set_color("green")   # R²

# Etiquetas y título
plt.title('Proteína')
plt.xlabel('Valor Bromatológico')
plt.ylabel('Valor Predicho')
plt.grid(True)
plt.tight_layout()
plt.savefig("PROTEINA_HOMERO_100.png", dpi=500, bbox_inches='tight')  
plt.show()
